# %% [markdown]
# # <div style="text-align: center"><font color='#dc2624' face='微软雅黑'>PyEcharts</font></div>
#
# ## <font color='#dc2624' face='微软雅黑'>目录</font><a name='toc'></a>
# ### 1. [**<font color='#dc2624' face='微软雅黑'>PyEcharts 101</font>**](#1)
#
# ### 2. [**<font color='#dc2624' face='微软雅黑'>坐标系图</font>**](#2)
# 1. [<font color='#2b4750' face='微软雅黑'>K 线图</font>](#2.1)
# 2. [<font color='#2b4750' face='微软雅黑'>折线图</font>](#2.2)
#
# ### 3. [**<font color='#dc2624' face='微软雅黑'>非坐标系图</font>**](#3)
# 1. [<font color='#2b4750' face='微软雅黑'>词云图</font>](#3.1)
# 2. [<font color='#2b4750' face='微软雅黑'>树形图</font>](#3.2)
#
# ### 4. [**<font color='#dc2624' face='微软雅黑'>多图</font>**](#4)
# 1. [<font color='#2b4750' face='微软雅黑'>并行图</font>](#4.1)
# 2. [<font color='#2b4750' face='微软雅黑'>时间轮播图</font>](#4.2)
# 3. [<font color='#2b4750' face='微软雅黑'>选项卡图</font>](#4.3)
# 4. [<font color='#2b4750' face='微软雅黑'>页面图</font>](#4.4)

# %% [markdown]
# <div style="text-align: right"> Use a picture. It’s worth a thousand words.</div>
# <div style="text-align: right"> — Arthur Brisbane</div>

# %% [markdown]
# # <font color='#dc2624' face='微软雅黑'>1. `PyEcharts` 101</font><a name='1'></a>
# [<font color='black' face='微软雅黑'>回到目录</font>](#toc)
#
# **`PyEcharts`** 顾名思义就是 Python 和 Echarts 的合体。Echarts 是一个由百度开源的数据可视化工具，凭借着良好的交互性，精巧的图表设计，得到了众多开发者的认可，而 Python 就不用多说了。当 Python 遇到了 Echarts，就变成了 **`PyEcharts`**。
#
# **`PyEcharts`** 的官网链接是 https://pyecharts.org。
#
# 在使用 **`PyEcharts`** 之前，需要引进它并检查它的版本，语法如下：

# %%
import pyecharts
pyecharts.__version__
# Out:
# '1.9.0'

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %% [markdown]
# 在 **`PyEcharts`** 中，一切皆配置 (options)。配置设定得越细就能画出越多细节。配置项有两种：22 个全局配置项和 17 个系列配置项。在后面会重点说明，尤其是全局配置项，它可通过 set_global_options() 方法来设置。借用其官网上的图来显示 6 个常见全局配置项。
#
# <img src='options.png' style="width:80%; height:80%;">

# %% [markdown]
# 在 **`PyEcharts`** 中图表可分两大类，单图和多图。
#
# - **单图**包括常见柱状和线形图等之外，还有“罕见”的 K 线图 (kline)、树形图 (treemap) 和词云图 (wordcount)
#
# - **多图**包括并行 (grid)、时间轮播 (timeline)、选项卡 (tab) 和顺序 (page) 四小类
#
# 在 v1.0 版本中，从 `pyecharts.charts` 中引入绘图元件。

# %%
from pyecharts.charts import Line, Kline, Bar, Pie, WordCloud, TreeMap
from pyecharts.charts import Grid, Timeline, Page, Tab
from pyecharts import options as opts
from pyecharts.globals import SymbolType
from pyecharts.commons.utils import JsCode

# %% [markdown]
# 前两行分别引入单图原件和多图原件、第三行引入配置模块，第四行引入的 SymbolType 用于设置词云的形状，第五行引入的 JsCode 用于运行 JavaScript 语句，在后面格式化字符串会用到。

# %% [markdown]
# # <font color='#dc2624' face='微软雅黑'>2. 坐标系图</font><a name='2'></a>
# [<font color='black' face='微软雅黑'>回到目录</font>](#toc)
#
# 首先用 YahooFinancials API 来下载若干资产的一年历史数据 (安装该 API 用 pip install yahoofinancials)：
#
# - 起始日：2018-12-01
# - 终止日：2020-12-01
# - 两只股票：蔚来 (NIO)、特斯拉 (TSLA)
# - 三个汇率：欧元美元 (EURUSD)、美元日元 (USDJPY)、英镑美元 (GBPUSD)
# - 两个加密货币：比特币 (BTC)、以太坊币 (ETH)
#
# 下面代码就是从 API 获取数据，股票用的是股票代号 (stock code)，而货币用的该 API 要求的格式，比如「欧元美元」用 EURUSD=X，而不是市场常见的 EURUSD，而「美元日元」用 JPY=X 而不是 USDJPY。

# %%
from yahoofinancials import YahooFinancials

# %%
start_date = '2018-12-01'
end_date = '2020-12-01'

stock_code = ['NIO', 'TSLA']
currency_code = ['EURUSD=X', 'JPY=X', 'GBPUSD=X']
cryptocurrency_code = ['BTC-USD', 'ETH-USD']

stock = YahooFinancials( stock_code )
currency = YahooFinancials( currency_code )
cryptocurrency = YahooFinancials( cryptocurrency_code )

stock_daily = stock.get_historical_price_data( start_date, end_date, 'daily' )
currency_daily = currency.get_historical_price_data( start_date, end_date, 'daily' )
cryptocurrency_daily = cryptocurrency.get_historical_price_data( start_date, end_date, 'daily' )

# %% [markdown]
# 该 API 返回结果是字典格式，样子非常丑陋，但信息齐全。画 K 线需要的开盘价 (open)、最高价 (high)、最低价 (low)、收盘价 (close) 都有。将上面的原始数据转换成数据帧，代码如下：

# %%
def data_converter( price_data, code, asset ):

    if asset == 'FX':
        code = str(code[3:] if code[:3]=='USD' else code) + '=X' 

    columns = ['open', 'close', 'low', 'high' ]
    price_dict = price_data[code]['prices']
    index = [ p['formatted_date'] for p in price_dict ]
    price = [ [p[c] for c in columns] for p in price_dict ]

    data = pd.DataFrame( price,
                         index=pd.Index(index, name='date'),
                         columns=pd.Index(columns, name='OHLC') )
    return data

# %% [markdown]
# ### <font color='#2b4750' face='微软雅黑'>2.1 K 线图</font><a name='2.1'></a>
# [<font color='black' face='微软雅黑'>回到章首</font>](#2)

# %%
stock = 'NIO'
data = data_converter( stock_daily, stock, 'EQ' )
data.head(3).append(data.tail(3))
# Out:
# OHLC             open      close        low       high
# date
# 2018-12-03   8.100000   7.580000   7.500000   8.130000
# 2018-12-04   7.600000   7.080000   7.050000   7.640000
# 2018-12-06   6.860000   7.370000   6.720000   7.370000
# 2020-11-25  49.980000  53.689999  49.250000  53.990002
# 2020-11-27  54.860001  54.000000  52.599998  55.549999
# 2020-11-30  54.209999  50.529999  48.180000  54.389999

# %%
date, price = data.index, data.values
date_list = pd.to_datetime(date).strftime('%Y/%m/%d').tolist()

kline = (
    Kline()
    .add_xaxis(date_list)
    .add_yaxis('', price.tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, 
                areastyle_opts=opts.AreaStyleOpts(opacity=0.5)
            ),
        ),
        title_opts=opts.TitleOpts(title=stock +' Chart'),
        datazoom_opts=[opts.DataZoomOpts(type_='inside')],
    )
)

kline.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="
#                     6.579999923706055
#                 ],
#                 [
#                     6.409999847412109,
#                     6.630000114440918,
#                     6.349999904632568,
#                     6.690000057220459
#                 ],
#                 [
#                     6.630000114440918,
#                     6.659999847412109,
#                     6.409999847412109,
#                     6.730000019073486
#                 ],
#                 [
#                     6.5,
#                     6.590000152587891,
#                     6.480000019073486,
#                     6.619999885559082
#                 ],
#                 [
#                     6.510000228881836,
#                     6.800000190734863,
#                     6.369999885559082,
#                     7.150000095367432
#                 ],
#                 [
#                     6.849999904632568,
#                     6.820000171661377,
#                     6.75,
#                     7.070000171661377
#                 ],
#                 [
#                     6.800000190734863,
#                     6.710000038146973,
#                     6.679999828338623,
#                     6.900000095367432
#                 ],
#                 [
#                     6.699999809265137,
#                     6.809999942779541,
#                     6.53000020980835,
#                     6.880000114440918
#                 ],
#                 [
#                     6.889999866485596,
#                     6.710000038146973,
#                     6.679999828338623,
#                     6.909999847412109
#                 ],
#                 [
#                     6.630000114440918,
#                     6.570000171661377,
#                     6.510000228881836,
#                     6.670000076293945
#                 ],
#                 [
#                     6.630000114440918,
#                     6.550000190734863,
#                     6.46999979019165,
#                     6.789999961853027
#                 ],
#                 [
#                     6.46999979019165,
#                     6.579999923706055,
#                     6.46999979019165,
#                     6.75
#                 ],
#                 [
#                     6.650000095

# %% [markdown]
# 在网页中展示可用 `render('xxx.html')` 语句。

# %%
kline.render(path=u'NIO Chart (v1.9.0).html');

# %% [markdown]
# 在 K 线图中添加折线，用 `overlap()` 函数。

# %%
kline = (
    Kline()
    .add_xaxis(date_list)
    .add_yaxis("K Line", price.tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, 
                areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        title_opts=opts.TitleOpts(title=stock+' Chart'),
        datazoom_opts=[opts.DataZoomOpts(type_='inside'),
                       opts.DataZoomOpts(type_='slider')],
    )
)

line = (
    Line()
    .add_xaxis(date_list)
    .add_yaxis(
            series_name='high',
            y_axis=data['high'].tolist(),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=1, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
            series_name='low',
            y_axis=data['low'].tolist(),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=1, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(datazoom_opts=[opts.DataZoomOpts(type_='inside'),
                                    opts.DataZoomOpts(type_='slider')] )
)
    
overlap_kline_line = kline.overlap(line)
overlap_kline_line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fbd209dbeb3b401b80fcb5e3b3455bd2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fbd209dbeb3b401b80fcb5e3b3455bd2 = echarts.init(
#                     document.getElementById('fbd209dbeb3b401b80fcb5e3b3455bd2'), 'white', {renderer: 'canvas'});
#                 var option_fbd209dbeb3b401b80fcb5e3b3455bd2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "K Line",
#             "data": [
#                 [
#                     8.100000381469727,
#                     7.579999923706055,
#                     7.5,
#                     8.130000114440918
#                 ],
#                 [
#                     7.599999904632568,
#                     7.079999923706055,
#                     7.050000190734863,
#                     7.639999866485596
#                 ],
#                 [
#                     6.860000133514404,
#                     7.369999885559082,
#                     6.71999979019165,
#                     7.369999885559082
#                 ],
#                 [
#                     7.360000133514404,
#                     6.989999771118164,
#                     6.960000038146973,
#                     7.380000114440918
#                 ],
#                 [
#                     7.03000020980835,
#                     6.710000038146973,
#                     6.679999828338623,
#                     6.909999847412109
#                 ],
#                 [
#                     6.630000114440918,
#                     6.570000171661377,
#                     6.510000228881836,
#                     6.670000076293945
#                 ],
#                 [
#                     6.630000114440918,
#                     6.550000190734863,
#                     6.46999979019165,
#                     6.789999961853027
#                 ],
#                 [
#                     6.46999979019165,
#                     6.579999923706055,
#                     6.46999979019165,
#                     6.75
#                 ],
#                 [

# %%
overlap_kline_line.render(path=u'NIO Chart (v1.9.0).html');

# %% [markdown]
# ### <font color='#2b4750' face='微软雅黑'>2.2 折线图</font><a name='2.2'></a>
# [<font color='black' face='微软雅黑'>回到章首</font>](#2)

# %%
label = 'BTC-USD'
data = data_converter( cryptocurrency_daily, label, 'CFX' )
data.head(3).append(data.tail(3))
# Out:
# OHLC                open         close           low          high
# date
# 2018-12-01   4024.464355   4214.671875   3969.710693   4309.377441
# 2018-12-02   4200.733398   4139.877930   4110.978516   4301.519531
# 2018-12-03   4147.323730   3894.130859   3840.446289   4155.979492
# 2020-11-29  17719.634766  18177.484375  17559.117188  18283.628906
# 2020-11-30  18178.322266  19625.835938  18178.322266  19749.263672
# 2020-12-01  19633.769531  18802.998047  18321.921875  19845.974609

# %%
#df = data['2018':'2019']
date, close = data.index, data['close'].values
date_list = pd.to_datetime(date).strftime('%Y/%m/%d').tolist()

lines = (
    Line()
    .add_xaxis(date_list)
    .add_yaxis(
            series_name='close',
            y_axis=close,
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=2, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title='比特币价格图'),
                     datazoom_opts=[opts.DataZoomOpts(type_='inside'),
                                    opts.DataZoomOpts(type_='slider')])
)

window_periods = [5, 20, 60]
for wp in window_periods:
    MA = data['close'].rolling(window=wp).mean()
    lines.add_yaxis(
        series_name='MA'+str(wp),
        y_axis=MA,
        is_smooth=True,
        is_hover_animation=False,
        linestyle_opts=opts.LineStyleOpts(width=1),
        label_opts=opts.LabelOpts(is_show=False),
    )

lines.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="321c5f5541324d3aa0dec7624203fd54" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_321c5f5541324d3aa0dec7624203fd54 = echarts.init(
#                     document.getElementById('321c5f5541324d3aa0dec7624203fd54'), 'white', {renderer: 'canvas'});
#                 var option_321c5f5541324d3aa0dec7624203fd54 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "close",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2018/12/01",
#                     4214.671875
#                 ],
#                 [
#                     "2018/12/02",
#                     4139.8779296875
#                 ],
#                 [
#                     "2018/12/03",
#                     3894.130859375
#                 ],
#                 [
#                     "2018/12/04",
#                     3956.893798828125
#                 ],
#                 [
#                     "2018/12/05",
#                     3753.994873046875
#                 ],
#                 [
#                     "2018/12/06",
#                     3521.101806640625
#                 ],
#                 [
#                     "2018/12/07",
#                     3419.937255859375
#                 ],
#                 [
#                     "2018/12/08",
#                     3476.11474609375
#                 ],
#                 [
#                     "2018/12/09",
#                     3614.234375
#                 ],
#                 [
#                     "2018/12/10",
#                     3502.656005859375
#                 ],
#                 [
#                     "2018/12/11",
#                     3424.588134765625
#                 ],
#                 [
#                     "2018/12/12",
#                     3486.9501953125
#                 ],
#                 [
#                     "2018/12/13",
#                     3313.67724609375
#                 ],
#                 [
#                     "2018/12/14",
#                     3242.48486328125
#                 ],
#                 [
#                     "2018/12/15",
#                     3236.76171875
#                 ],
#                 [
#                     "2018/12/16",
#                     3252.839111328125
#                 ],
#                 [
#                     "2018/12/17",
#                     3545.86474609375
#                 ],
#                 [
#                     "2018/12/18",
#                     3696.05908203125
#                 ],
#                 [
#                     "2018/12/19",
#                     3745.95068359375
#                 ],
#                 [
#                     "2018/12/20",
#                     4134.44140625
#                 ],
#                 [
#                     "2018/12/21",
#                     3896.543701171875
#                 ],
#                 [
#                     "2018/12/22",
#                     4014.1826171875
#                 ],
#                 [
#                     "2018/12/23",
#                     3998.980224609375
#                 ],
#                 [
#                     "2018/12/24",
#                     4078.59912109375
#                 ],
#                 [
#                     "2018/12/25",
#                     3815.49072265625
#                 ],
#                 [
#                     "2018/12/26",
#                     3857.297607421875
#                 ],
#                 [
#                     "2018/12/27",
#                     3654.83349609375
#                 ],
#                 [
#                     "2018/12/28",
#                     3923.918701171875
#                 ],
#                 [
#                     "2018/12/29",
#                     3820.40869140625
#                 ],
#                 [
#                     "2018/12/30",
#                     3865.95263671875
#                 ],
#                 [
#                     "2018/12/31",
#                     3742.700439453125
#                 ],
#                 [
#                     "2019/01/01",
#                     3843.52001953125
#                 ],
#                 [
#                     "2019/01/02",
#                     3943.409423828125
#                 ],
#                 [
#                     "2019/01/03",
#                     3836.7412109375
#                 ],
#                 [
#                     "2019/01/04",
#                     3857.717529296875
#                 ],
#                 [
#                     "2019/01/05",
#                     3845.194580078125
#                 ],
#                 [
#                     "2019/01/06",
#                     4076.632568359375
#                 ],
#                 [
#                     "2019/01/07",
#                     4025.248291015625
#                 ],
#                 [
#                     "2019/01/08",
#                     4030.847900390625
#                 ],
#                 [
#                     "2019/01/09",
#                     4035.29638671875
#                 ],
#                 [
#                     "2019/01/10",
#                     3678.924560546875
#                 ],
#                 [
#                     "2019/01/11",
#                     3687.365478515625
#                 ],
#                 [
#                     "2019/01/12",
#                     3661.301025390625
#                 ],
#                 [
#                     "2019/01/13",
#                     3552.953125
#                 ],
#                 [
#                     "2019/01/14",
#                     3706.05224609375
#                 ],
#                 [
#                     "2019/01/15",
#                     3630.67529296875
#                 ],
#                 [
#                     "2019/01/16",
#                     3655.0068359375
#                 ],
#                 [
#                     "2019/01/17",
#                     3678.56396484375
#                 ],
#                 [
#                     "2019/01/18",
#                     3657.83935546875
#                 ],
#                 [
#                     "2019/01/19",
#                     3728.568359375
#                 ],
#                 [
#                     "2019/01/20",
#                     3601.013671875
#                 ],
#                 [
#                     "2019/01/21",
#                     3576.032470703125
#                 ],
#                 [
#                     "2019/01/22",
#                     3604.5771484375
#                 ],
#                 [
#                     "2019/01/23",
#                     3585.123046875
#                 ],
#                 [
#                     "2019/01/24",
#                     3600.865478515625
#                 ],
#                 [
#                     "2019/01/25",
#                     3599.765869140625
#                 ],
#                 [
#                     "2019/01/26",
#                     3602.46044921875
#                 ],
#                 [
#                     "2019/01/27",
#                     3583.9658203125
#                 ],
#                 [
#                     "2019/01/28",
#                     3470.450439453125
#                 ],
#                 [
#                     "2019/01/29",
#                     3

# %% [markdown]
# # <font color='#dc2624' face='微软雅黑'>3. 非坐标系图</font><a name='3'></a>
# [<font color='black' face='微软雅黑'>回到目录</font>](#toc)
#
# ### <font color='#2b4750' face='微软雅黑'>3.1 词云图</font><a name='3.1'></a>
# [<font color='black' face='微软雅黑'>回到章首</font>](#3)
#
# 词云图是对文本中出现频率较高的“关键词”做可视化，它过滤掉低频低质的文本信息，使得浏览者一眼扫过文本就可领略主旨。以下用笔者个人公众号「王的机器」用户分布信息来做词云图，首先收集地区名称和属于该地区的用户个数。

# %%
attr = ['北京', '上海', '深圳', '广州', '杭州', '美国', '南京', '成都', '武汉', '西安', 
        '新加坡', '重庆', '长沙', '天津', '苏州', '合肥', '郑州', '厦门', '香港',  '济南', 
        '大连', '青岛', '佛山', '沈阳', '福州', '东莞', '哈尔滨', '加拿大', '昆明', '南昌', 
        '秦皇岛', '宁波', '珠海', '澳大利亚', '长春', '兰州', '无锡', '南宁', '烟台', '石家庄', 
        '英国', '日本', '太原', '德国', '贵阳', '徐州', '温州', '呼和浩特', '保定', '嘉兴']
count = [5209, 4314, 2247, 1503, 1399, 1028, 927, 904, 845, 796,
         654, 410, 405, 402, 333, 314, 292, 263, 245, 242,
         239, 225, 212, 210, 196, 178, 175, 164, 152, 151,
         145, 144, 140, 133, 129, 128, 120, 120, 109,
         104, 104, 98, 91, 87,86, 74, 65, 62, 60]

# %%
wordcloud = (
    WordCloud()
    .add(series_name="",
         data_pair=[pair for pair in zip(attr,count)], 
         word_size_range=[20, 100]
        )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="王的机器用户分析", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
)

wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="980049de6137469799c09a1db6b8eaea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_980049de6137469799c09a1db6b8eaea = echarts.init(
#                     document.getElementById('980049de6137469799c09a1db6b8eaea'), 'white', {renderer: 'canvas'});
#                 var option_980049de6137469799c09a1db6b8eaea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 5209,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,140,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 4314,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,145,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 2247,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,100,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 1503,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,154,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 1399,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(123,92,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f8e\u56fd",
#                     "value": 1028,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,43,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": 927,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,107,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 904,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,138,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": 845,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,74,109)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": 796,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,6,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u52a0\u5761",
#                     "value": 654,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,65,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 410,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,63,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": 405,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,2,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 402,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,5,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": 333,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,118,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": 314,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,122,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": 292,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,87,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": 263,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,155,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 245,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,153,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": 242,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,110,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u8fde",
#                     "value": 239,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,8,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 225,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(13

# %%
wordcloud = (
    WordCloud()
    .add(series_name="",
         data_pair=[pair for pair in zip(attr,count)], 
         word_size_range=[20, 100],
         shape=SymbolType.DIAMOND)
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="王的机器用户分析", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
)

wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="2d904cec46b14b86a3398ac0de8da416" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_2d904cec46b14b86a3398ac0de8da416 = echarts.init(
#                     document.getElementById('2d904cec46b14b86a3398ac0de8da416'), 'white', {renderer: 'canvas'});
#                 var option_2d904cec46b14b86a3398ac0de8da416 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 5209,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,111,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 4314,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,91,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 2247,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,74,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 1503,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(85,3,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 1399,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,16,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f8e\u56fd",
#                     "value": 1028,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,7,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": 927,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,131,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 904,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,118,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": 845,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,37,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": 796,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(73,157,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u52a0\u5761",
#                     "value": 654,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,77,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 410,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,34,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": 405,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,37,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 402,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,116,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": 333,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,19,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": 314,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,135,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": 292,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(96,143,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": 263,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,93,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 245,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,49,18)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": 242,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,9,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u8fde",
#                     "value": 239,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,5,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 225,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(135,47,47)"

# %% [markdown]
# ### <font color='#2b4750' face='微软雅黑'>3.2 树形图</font><a name='3.2'></a>
# [<font color='black' face='微软雅黑'>回到章首</font>](#3)
#
# 树形图可在嵌套的且不同大小和颜色矩形中显示数据，数据可以用层级方式结构化。用 `Pandas` 读取并打印数据。
#
# 数据帧中四列分别是美股的股票代号 (code)、市值 (market_cap)、日收益率 (return) 和行业 (sector)。

# %%
data = pd.read_csv( 'US Stock Info.csv' )
data.head()
# Out:
#    code    market_cap    return           sector
# 0  AAPL  8.860000e+11  0.012412       TECHNOLOGY
# 1   ABT  1.430000e+11  0.006442       HEALTHCARE
# 2  GOLD  2.360000e+10 -0.006642  BASIC_MATERIALS
# 3  ADSK  3.630000e+10 -0.001089       TECHNOLOGY
# 4  ADBE  1.370000e+11  0.007730       TECHNOLOGY

# %%
def print_groups( group_obj ):
    for name, group in group_obj:
        print( name )
        print( group.head() )

# %%
grouped = data.groupby(['sector'])
print_groups(grouped)
# Out:
# BASIC_MATERIALS
#      code    market_cap    return           sector
# 2    GOLD  2.360000e+10 -0.006642  BASIC_MATERIALS
# 16    APD  4.870000e+10 -0.007310  BASIC_MATERIALS
# 55    ECL  5.760000e+10  0.004327  BASIC_MATERIALS
# 115   NEM  2.890000e+10 -0.011208  BASIC_MATERIALS
# 133   PPG  2.700000e+10  0.003070  BASIC_MATERIALS
# COMMUNICATION_SERVICES
#       code    market_cap    return                  sector
# 25     BCE  4.210000e+10 -0.001067  COMMUNICATION_SERVICES
# 42   CMCSA  1.870000e+11 -0.004099  COMMUNICATION_SERVICES
# 141      T  2.330000e+11 -0.017549  COMMUNICATION_SERVICES
# 195   DISH  1.750000e+10  0.005925  COMMUNICATION_SERVICES
# 201    RCI  2.740000e+10  0.000000  COMMUNICATION_SERVICES
# CONSUMER_CYCLICAL
#    code    market_cap    return             sector
# 20  AZO  2.730000e+10  0.011951  CONSUMER_CYCLICAL
# 24  BBY  1.740000e+10  0.022599  CONSUMER_CYCLICAL
# 29  BLL  2.220000e+10  0.006373  CONSUMER_CYCLICAL
# 52  DIS  2.470000e+11 -0.006956  CONSUMER_CYCLICAL
# 62    F  3.920000e+10  0.005638  CONSUMER_CYCLICAL
# CONSUMER_DEFENSIVE
#     code    market_cap    return              sector
# 6    ADM  2.240000e+10  0.011875  CONSUMER_DEFENSIVE
# 27  BF.B  2.710000e+10  0.012920  CONSUMER_DEFENSIVE
# 34  CCEP  2.710000e+10  0.001736  CONSUMER_DEFENSIVE
# 38   CHD  1.900000e+10 -0.008978  CONSUMER_DEFENSIVE
# 40    CL  6.270000e+10 -0.013110  CONSUMER_DEFENSIVE
# ENERGY
#     code    market_cap    return  sector
# 9    HES  1.740000e+10  0.012374  ENERGY
# 58   EOG  4.940000e+10  0.007803  ENERGY
# 74   HAL  1.900000e+10  0.005545  ENERGY
# 86   IMO  2.110000e+10 -0.003280  ENERGY
# 121  OKE  2.720000e+10 -0.002274  ENERGY
# FINANCIAL_SERVICES
#    code    market_cap    return              sector
# 8   AFL  4.050000e+10 -0.004033  FINANCIAL_SERVICES
# 10  AIG  4.640000e+10  0.007749  FINANCIAL_SERVICES
# 15  AON  4.590000e+10  0.003154  FINANCIAL_SERVICES
# 19  AXP  1.020000e+11  0.013046  FINANCIAL_SERVICES
# 22  BAC  2.670000e+11  0.020208  FINANCIAL_SERVICES
# HEALTHCARE
#     code    market_cap    return      sector
# 1    ABT  1.430000e+11  0.006442  HEALTHCARE
# 14  AMGN  1.070000e+11  0.000342  HEALTHCARE
# 23   BAX  3.990000e+10  0.007476  HEALTHCARE
# 26   BDX  6.480000e+10  0.007341  HEALTHCARE
# 30   BMY  7.530000e+10 -0.016257  HEALTHCARE
# INDUSTRIALS
#    code    market_cap    return       sector
# 13  AME  1.970000e+10  0.008982  INDUSTRIALS
# 18  ADP  7.300000e+10  0.004493  INDUSTRIALS
# 21   BA  1.990000e+11  0.000424  INDUSTRIALS
# 33  CAT  7.190000e+10  0.010287  INDUSTRIALS
# 44   CP  3.250000e+10 -0.010867  INDUSTRIALS
# REAL_ESTATE
#      code    market_cap    return       sector
# 76   WELL  3.340000e+10 -0.010571  REAL_ESTATE
# 173    WY  1.800000e+10  0.013031  REAL_ESTATE
# 182   EQR  2.880000e+10 -0.001796  REAL_ESTATE
# 184   SPG  4.990000e+10 -0.012118  REAL_ESTATE
# 187   ESS  1.950000e+10 -0.002427  REAL_ESTATE
# TECHNOLOGY
#     code    market_cap    return      sector
# 0   AAPL  8.860000e+11  0.012412  TECHNOLOGY
# 3   ADSK  3.630000e+10 -0.001089  TECHNOLOGY
# 4   ADBE  1.370000e+11  0.007730  TECHNOLOGY
# 5    ADI  3.940000e+10  0.058298  TECHNOLOGY
# 11  AMAT  4.040000e+10  0.039759  TECHNOLOGY
# UTILITIES
#    code    market_cap    return     sector
# 7   AEP  4.390000e+10 -0.005807  UTILITIES
# 49    D  6.050000e+10 -0.005540  UTILITIES
# 53  DTE  2.350000e+10 -0.002256  UTILITIES
# 54  DUK  6.280000e+10 -0.009075  UTILITIES
# 56   ED  2.850000e+10 -0.012118  UTILITIES

# %%
group_value = grouped.apply( lambda df: np.sum(df['market_cap']) )
group_value
# Out:
# sector
# BASIC_MATERIALS           3.367000e+11
# COMMUNICATION_SERVICES    1.067600e+12
# CONSUMER_CYCLICAL         2.946600e+12
# CONSUMER_DEFENSIVE        2.150900e+12
# ENERGY                    1.270500e+12
# FINANCIAL_SERVICES        4.461700e+12
# HEALTHCARE                3.076000e+12
# INDUSTRIALS               2.365500e+12
# REAL_ESTATE               5.053000e+11
# TECHNOLOGY                5.941700e+12
# UTILITIES                 6.931000e+11
# dtype: float64

# %% [markdown]
# 接下来编写一个函数将数据帧转换成 **`PyEcharts`** 中树形图需要的数据格式。

# %%
data_for_treemap = []

for i, grp in enumerate(grouped):
    
    total_mktcap, sector = group_value[i], group_value.index[i]
    code, r, mktcap = grp[1]['code'], grp[1]['return'], grp[1]['market_cap']

    children = []
    
    for j in range(len(code)):
        
        j_data = { 'value' : mktcap.iloc[j], 
                   'name': [code.iloc[j], r.iloc[j], sector] }
        
        children.append( j_data )
    
    i_data = { 'value' : total_mktcap,
               'name': sector,
               'children': children }
    
    data_for_treemap.append( i_data )

data_for_treemap
# Out:
# [{'value': 336700000000.0,
#   'name': 'BASIC_MATERIALS',
#   'children': [{'value': 23600000000.0,
#     'name': ['GOLD', -0.006642, 'BASIC_MATERIALS']},
#    {'value': 48700000000.0, 'name': ['APD', -0.00731, 'BASIC_MATERIALS']},
#    {'value': 57600000000.0, 'name': ['ECL', 0.004327, 'BASIC_MATERIALS']},
#    {'value': 28900000000.0, 'name': ['NEM', -0.011208, 'BASIC_MATERIALS']},
#    {'value': 27000000000.0, 'name': ['PPG', 0.00307, 'BASIC_MATERIALS']},
#    {'value': 43500000000.0, 'name': ['SHW', -0.004979, 'BASIC_MATERIALS']},
#    {'value': 17900000000.0, 'name': ['VMC', 0.009007, 'BASIC_MATERIALS']},
#    {'value': 28100000000.0, 'name': ['SCCO', 0.009154, 'BASIC_MATERIALS']},
#    {'value': 31000000000.0, 'name': ['LYB', 0.056313, 'BASIC_MATERIALS']},
#    {'value': 30400000000.0, 'name': ['NTR', 0.004647, 'BASIC_MATERIALS']}]},
#  {'value': 1067600000000.0,
#   'name': 'COMMUNICATION_SERVICES',
#   'children': [{'value': 42100000000.0,
#     'name': ['BCE', -0.001067, 'COMMUNICATION_SERVICES']},
#    {'value': 187000000000.0,
#     'name': ['CMCSA', -0.004099, 'COMMUNICATION_SERVICES']},
#    {'value': 233000000000.0,
#     'name': ['T', -0.017549000000000002, 'COMMUNICATION_SERVICES']},
#    {'value': 17500000000.0,
#     'name': ['DISH', 0.005925, 'COMMUNICATION_SERVICES']},
#    {'value': 27400000000.0, 'name': ['RCI', 0.0, 'COMMUNICATION_SERVICES']},
#    {'value': 232000000000.0,
#     'name': ['VZ', -0.018703, 'COMMUNICATION_SERVICES']},
#    {'value': 22700000000.0,
#     'name': ['TU', 0.002654, 'COMMUNICATION_SERVICES']},
#    {'value': 92800000000.0,
#     'name': ['AMT', -0.012145999999999999, 'COMMUNICATION_SERVICES']},
#    {'value': 19300000000.0,
#     'name': ['LBTYK', 0.016797, 'COMMUNICATION_SERVICES']},
#    {'value': 65500000000.0,
#     'name': ['TMUS', -0.0042829999999999995, 'COMMUNICATION_SERVICES']},
#    {'value': 88300000000.0,
#     'name': ['CHTR', 0.0035020000000000003, 'COMMUNICATION_SERVICES']},
#    {'value': 18600000000.0,
#     'name': ['LBRDK', 0.0019079999999999998, 'COMMUNICATION_SERVICES']},
#    {'value': 21400000000.0,
#     'name': ['ATUS', 0.0016190000000000002, 'COMMUNICATION_SERVICES']}]},
#  {'value': 2946600000000.0,
#   'name': 'CONSUMER_CYCLICAL',
#   'children': [{'value': 27300000000.0,
#     'name': ['AZO', 0.011951, 'CONSUMER_CYCLICAL']},
#    {'value': 17400000000.0, 'name': ['BBY', 0.022599, 'CONSUMER_CYCLICAL']},
#    {'value': 22200000000.0,
#     'name': ['BLL', 0.006372999999999999, 'CONSUMER_CYCLICAL']},
#    {'value': 247000000000.0, 'name': ['DIS', -0.006956, 'CONSUMER_CYCLICAL']},
#    {'value': 39200000000.0,
#     'name': ['F', 0.005638000000000001, 'CONSUMER_CYCLICAL']},
#    {'value': 218000000000.0, 'name': ['HD', 0.004158, 'CONSUMER_CYCLICAL']},
#    {'value': 17400000000.0, 'name': ['IP', -0.028025, 'CONSUMER_CYCLICAL']},
#    {'value': 75400000000.0, 'name': ['LOW', -0.004651, 'CONSUMER_CYCLICAL']},
#    {'value': 154000000000.0, 'name': ['MCD', -0.020583, 'CONSUMER_CYCLICAL']},
#    {'value': 130000000000.0, 'name': ['NKE', -0.010071, 'CONSUMER_CYCLICAL']},
#    {'value': 17300000000.0, 'name': ['OMC', -0.008078, 'CONSUMER_CYCLICAL']},
#    {'value': 36000000000.0,
#     'name': ['ROST', -0.008745999999999999, 'CONSUMER_CYCLICAL']},
#    {'value': 99200000000.0, 'name': ['SBUX', -0.006669, 'CONSUMER_CYCLICAL']},
#    {'value': 62600000000.0,
#     'name': ['TJX', -0.0053939999999999995, 'CONSUMER_CYCLICAL']},
#    {'value': 34000000000.0, 'name': ['VFC', 0.01157, 'CONSUMER_CYCLICAL']},
#    {'value': 18000000000.0, 'name': ['CBS', -0.009502, 'CONSUMER_CYCLICAL']},
#    {'value': 30100000000.0,
#     'name': ['ORLY', 0.0067480000000000005, 'CONSUMER_CYCLICAL']},
#    {'value': 25900000000.0, 'name': ['RCL', 0.020503, 'CONSUMER_CYCLICAL']},
#    {'value': 25000000000.0, 'name': ['SIRI', 0.020677, 'CONSUMER_CYCLICAL']},
#    {'value': 916000000000.0, 'name': ['AMZN', 0.03138, 'CONSUMER_CYCLICAL']},
#    {'value': 33200000000.0, 'name': ['YUM', -0.004034, 'CONSUMER_CYCLICAL']},
#    {'value': 77100000000.0,
#     'name': ['BKNG', 0.0016809999999999998, 'CONSUMER_CYCLICAL']},
#    {'value': 154000000000.0, 'name': ['NFLX', -0.024363, 'CONSUMER_CYCLICAL']},
#    {'value': 38100000000.0, 'name': ['CCL', 0.018189, 'CONSUMER_CYCLICAL']},
#    {'value': 33200000000.0, 'name': ['EBAY', 0.015991, 'CONSUMER_CYCLICAL']},
#    {'value': 44200000000.0, 'name': ['MAR', 0.001736, 'CONSUMER_CYCLICAL']},
#    {'value': 44900000000.0, 'name': ['LVS', 0.039237, 'CONSUMER_CYCLICAL']},
#    {'value': 18100000000.0, 'name': ['EXPE', -0.006852, 'CONSUMER_CYCLICAL']},
#    {'value': 20000000000.0, 'name': ['CMG', 0.014588, 'CONSUMER_CYCLICAL']},
#    {'value': 22300000000.0, 'name': ['LULU', -0.006212, 'CONSUMER_CYCLICAL']},
#    {'value': 30400000000.0, 'name': ['MELI', 0.021221, 'CONSUMER_CYCLICAL']},
#    {'value': 19700000000.0,
#     'name': ['ULTA', -0.0034020000000000005, 'CONSUMER_CYCLICAL']},
#    {'value': 37900000000.0, 'name': ['TSLA', 0.041538, 'CONSUMER_CYCLICAL']},
#    {'value': 51100000000.0,
#     'name': ['GM', 0.014652000000000002, 'CONSUMER_CYCLICAL']},
#    {'value': 19500000000.0, 'name': ['APTV', 0.031331, 'CONSUMER_CYCLICAL']},
#    {'value': 27100000000.0, 'name': ['HLT', 0.005297, 'CONSUMER_CYCLICAL']},
#    {'value': 26500000000.0, 'name': ['FCAU', 0.018182, 'CONSUMER_CYCLICAL']},
#    {'value': 37300000000.0, 'name': ['RACE', 0.023072, 'CONSUMER_CYCLICAL']}]},
#  {'value': 2150900000000.0,
#   'name': 'CONSUMER_DEFENSIVE',
#   'children': [{'value': 22400000000.0,
#     'name': ['ADM', 0.011875, 'CONSUMER_DEFENSIVE']},
#    {'value': 27100000000.0, 'name': ['BF.B', 0.01292, 'CONSUMER_DEFENSIVE']},
#    {'value': 27100000000.0, 'name': ['CCEP', 0.001736, 'CONSUMER_DEFENSIVE']},
#    {'value': 19000000000.0, 'name': ['CHD', -0.008978, 'CONSUMER_DEFENSIVE']},
#    {'value': 62700000000.0, 'name': ['CL', -0.01311, 'CONSUMER_DEFENSIVE']},
#    {'value': 20000000000.0, 'name': ['CLX', 0.001086, 'CONSUMER_DEFENSIVE']},
#    {'value': 113000000000.0, 'name': ['COST', 0.003281, 'CONSUMER_DEFENSIVE']},
#    {'value': 30700000000.0, 'name': ['GIS', -0.009265, 'CONSUMER_DEFENSIVE']},
#    {'value': 35700000000.0, 'name': ['MNST', -0.002427, 'CONSUMER_DEFENSIVE']},
#    {'value': 22100000000.0, 'name': ['HRL', -0.014031, 'CONSUMER_DEFENSIVE']},
#    {'value': 28600000000.0, 'name': ['HSY', -0.009709, 'CONSUMER_DEFENSIVE']},
#    {'value': 18600000000.0, 'name': ['K', -0.02179, 'CONSUMER_DEFENSIVE']},
#    {'value': 46300000000.0,
#     'name': ['KMB', -0.0016309999999999999, 'CONSUMER_DEFENSIVE']},
#    {'value': 219000000000.0, 'name': ['KO', -0.002176, 'CONSUMER_DEFENSIVE']},
#    {'value': 19700000000.0, 'name': ['KR', 0.019223, 'CONSUMER_DEFENSIVE']},
#    {'value': 20700000000.0, 'name': ['MKC', -0.00545, 'CONSUMER_DEFENSIVE']},
#    {'value': 95800000000.0,
#     'name': ['MO', -0.0033090000000000003, 'CONSUMER_DEFENSIVE']},
#    {'value': 187000000000.0,
#     'name': ['PEP', 0.0008990000000000001, 'CONSUMER_DEFENSIVE']},
#    {'value': 273000000000.0,
#     'name': ['PG', -0.00045999999999999996, 'CONSUMER_DEFENSIVE']},
#    {'value': 36900000000.0, 'name': ['SYY', 0.003077, 'CONSUMER_DEFENSIVE']},
#    {'value': 30100000000.0, 'name': ['TSN', 0.000728, 'CONSUMER_DEFENSIVE']},
#    {'value': 47800000000.0, 'name': ['WBA', 0.006542, 'CONSUMER_DEFENSIVE']},
#    {'value': 307000000000.0,
#     'name': ['WMT', 0.013996999999999999, 'CONSUMER_DEFENSIVE']},
#    {'value': 24700000000.0, 'name': ['DLTR', 0.011498, 'CONSUMER_DEFENSIVE']},
#    {'value': 64400000000.0,
#     'name': ['EL', 0.0062770000000000005, 'CONSUMER_DEFENSIVE']},
#    {'value': 44900000000.0, 'name': ['TGT', 0.007945, 'CONSUMER_DEFENSIVE']},
#    {'value': 78100000000.0, 'name': ['MDLZ', 0.003333, 'CONSUMER_DEFENSIVE']},
#    {'value': 36600000000.0, 'name': ['STZ', 0.01884, 'CONSUMER_DEFENSIVE']},
#    {'value': 120000000000.0, 'name': ['PM', -0.015609, 'CONSUMER_DEFENSIVE']},
#    {'value': 34900000000.0, 'name': ['DG', 0.013444, 'CONSUMER_DEFENSIVE']},
#    {'value': 37000000000.0, 'name': ['KHC', 0.055014, 'CONSUMER_DEFENSIVE']}]},
#  {'value': 1270500000000.0,
#   'name': 'ENERGY',
#   'children': [{'value': 17400000000.0, 'name': ['HES', 0.012374, 'ENERGY']},
#    {'value': 49400000000.0, 'name': ['EOG', 0.007803, 'ENERGY']},
#    {'value': 19000000000.0, 'name': ['HAL', 0.0055450000000000004, 'ENERGY']},
#    {'value': 21100000000.0, 'name': ['IMO', -0.00328, 'ENERGY']},
#    {'value': 27200000000.0, 'name': ['OKE', -0.002274, 'ENERGY']},
#    {'value': 35800000000.0, 'name': ['OXY', 0.001464, 'ENERGY']},
#    {'value': 49100000000.0, 'name': ['SLB', -0.003933, 'ENERGY']},
#    {'value': 46200000000.0, 'name': ['TRP', -0.008073, 'ENERGY']},
#    {'value': 31700000000.0, 'name': ['VLO', 0.015257, 'ENERGY']},
#    {'value': 317000000000.0, 'name': ['XOM', 0.004292, 'ENERGY']},
#    {'value': 47700000000.0, 'name': ['SU', -0.002624, 'ENERGY']},
#    {'value': 24400000000.0, 'name': ['PXD', -0.0017929999999999999, 'ENERGY']},
#    {'value': 71600000000.0, 'name': ['ENB', -0.002817, 'ENERGY']},
#    {'value': 32100000000.0, 'name': ['CNQ', 0.0041140000000000005, 'ENERGY']},
#    {'value': 233000000000.0, 'name': ['CVX', 0.006504, 'ENERGY']},
#    {'value': 67000000000.0, 'name': ['COP', 0.005259000000000001, 'ENERGY']},
#    {'value': 20000000000.0, 'name': ['CXO', -0.006589, 'ENERGY']},
#    {'value': 47300000000.0, 'name': ['KMI', -0.011837, 'ENERGY']},
#    {'value': 31600000000.0, 'name': ['MPC', 0.014687, 'ENERGY']},
#    {'value': 18600000000.0, 'name': ['PBA', 0.001098, 'ENERGY']},
#    {'value': 39000000000.0, 'name': ['PSX', 0.004327, 'ENERGY']},
#    {'value': 24300000000.0, 'name': ['BHGE', 0.003861, 'ENERGY']}]},
#  {'value': 4461700000000.0,
#   'name': 'FINANCIAL_SERVICES',
#   'children': [{'value': 40500000000.0,
#     'name': ['AFL', -0.004033, 'FINANCIAL_SERVICES']},
#    {'value': 46400000000.0, 'name': ['AIG', 0.007749, 'FINANCIAL_SERVICES']},
#    {'value': 45900000000.0, 'name': ['AON', 0.003154, 'FINANCIAL_SERVICES']},
#    {'value': 102000000000.0, 'name': ['AXP', 0.013046, 'FINANCIAL_SERVICES']},
#    {'value': 267000000000.0, 'name': ['BAC', 0.020208, 'FINANCIAL_SERVICES']},
#    {'value': 43000000000.0, 'name': ['BK', 0.011036, 'FINANCIAL_SERVICES']},
#    {'value': 64400000000.0,
#     'name': ['BNS', 0.0056630000000000005, 'FINANCIAL_SERVICES']},
#    {'value': 155000000000.0, 'name': ['C', 0.021852, 'FINANCIAL_SERVICES']},
#    {'value': 19800000000.0, 'name': ['FITB', 0.006711, 'FINANCIAL_SERVICES']},
#    {'value': 34800000000.0, 'name': ['MFC', -0.004479, 'FINANCIAL_SERVICES']},
#    {'value': 55900000000.0,
#     'name': ['SPGI', 0.010948999999999999, 'FINANCIAL_SERVICES']},
#    {'value': 50300000000.0, 'name': ['MMC', 0.000101, 'FINANCIAL_SERVICES']},
#    {'value': 22900000000.0, 'name': ['MTB', 0.01086, 'FINANCIAL_SERVICES']},
#    {'value': 19200000000.0, 'name': ['NTRS', 0.001076, 'FINANCIAL_SERVICES']},
#    {'value': 48200000000.0, 'name': ['PGR', -0.007214, 'FINANCIAL_SERVICES']},
#    {'value': 57800000000.0,
#     'name': ['SCHW', 0.0072109999999999995, 'FINANCIAL_SERVICES']},
#    {'value': 39100000000.0, 'name': ['TRV', -0.001471, 'FINANCIAL_SERVICES']},
#    {'value': 21400000000.0, 'name': ['STT', 0.010775, 'FINANCIAL_SERVICES']},
#    {'value': 28300000000.0, 'name': ['STI', 0.016592, 'FINANCIAL_SERVICES']},
#    {'value': 25300000000.0, 'name': ['TROW', 0.012111, 'FINANCIAL_SERVICES']},
#    {'value': 208000000000.0, 'name': ['WFC', 0.014032, 'FINANCIAL_SERVICES']},
#    {'value': 68200000000.0, 'name': ['CB', -0.003145, 'FINANCIAL_SERVICES']},
#    {'value': 509000000000.0,
#     'name': ['BRK.B', 0.005928, 'FINANCIAL_SERVICES']},
#    {'value': 47800000000.0, 'name': ['BMO', 0.0051, 'FINANCIAL_SERVICES']},
#    {'value': 42500000000.0, 'name': ['COF', 0.001662, 'FINANCIAL_SERVICES']},
#    {'value': 18300000000.0, 'name': ['BAP', -0.000218, 'FINANCIAL_SERVICES']},
#    {'value': 112000000000.0,
#     'name': ['RY', 0.0032189999999999996, 'FINANCIAL_SERVICES']},
#    {'value': 19800000000.0, 'name': ['HIG', -0.002729, 'FINANCIAL_SERVICES']},
#    {'value': 34300000000.0, 'name': ['AABA', 0.064235, 'FINANCIAL_SERVICES']},
#    {'value': 104000000000.0,
#     'name': ['TD', 0.0024690000000000003, 'FINANCIAL_SERVICES']},
#    {'value': 29000000000.0, 'name': ['AMTD', 0.007292, 'FINANCIAL_SERVICES']},
#    {'value': 38000000000.0,
#     'name': ['BBT', 0.015466999999999998, 'FINANCIAL_SERVICES']},
#    {'value': 72800000000.0,
#     'name': ['MS', 0.014055000000000002, 'FINANCIAL_SERVICES']},
#    {'value': 34800000000.0, 'name': ['CM', 0.005267, 'FINANCIAL_SERVICES']},
#    {'value': 71000000000.0, 'name': ['GS', 0.022619, 'FINANCIAL_SERVICES']},
#    {'value': 69000000000.0,
#     'name': ['BLK', -0.0008560000000000001, 'FINANCIAL_SERVICES']},
#    {'value': 23900000000.0,
#     'name': ['SLF', -0.006540000000000001, 'FINANCIAL_SERVICES']},
#    {'value': 46000000000.0, 'name': ['MET', 0.00207, 'FINANCIAL_SERVICES']},
#    {'value': 47200000000.0, 'name': ['BAM', -0.00461, 'FINANCIAL_SERVICES']},
#    {'value': 36400000000.0, 'name': ['MCO', 0.011115, 'FINANCIAL_SERVICES']},
#    {'value': 24300000000.0, 'name': ['WLTW', 0.008457, 'FINANCIAL_SERVICES']},
#    {'value': 40500000000.0, 'name': ['PRU', 0.003421, 'FINANCIAL_SERVICES']},
#    {'value': 32900000000.0,
#     'name': ['TRI', -0.017646000000000002, 'FINANCIAL_SERVICES']},
#    {'value': 72700000000.0, 'name': ['CME', 0.004848, 'FINANCIAL_SERVICES']},
#    {'value': 33600000000.0,
#     'name': ['ALL', 0.0008939999999999999, 'FINANCIAL_SERVICES']},
#    {'value': 358000000000.0, 'name': ['JPM', 0.010813, 'FINANCIAL_SERVICES']},
#    {'value': 84200000000.0,
#     'name': ['USB', 0.0049380000000000005, 'FINANCIAL_SERVICES']},
#    {'value': 20300000000.0, 'name': ['AMP', 0.008941, 'FINANCIAL_SERVICES']},
#    {'value': 48500000000.0, 'name': ['ICE', 0.007847, 'FINANCIAL_SERVICES']},
#    {'value': 272000000000.0, 'name': ['MA', 0.000188, 'FINANCIAL_SERVICES']},
#    {'value': 25300000000.0, 'name': ['DFS', 0.000768, 'FINANCIAL_SERVICES']},
#    {'value': 20700000000.0,
#     'name': ['MSCI', 0.015483000000000002, 'FINANCIAL_SERVICES']},
#    {'value': 385000000000.0, 'name': ['V', 0.004764, 'FINANCIAL_SERVICES']},
#    {'value': 20200000000.0, 'name': ['KKR', -0.000834, 'FINANCIAL_SERVICES']},
#    {'value': 23000000000.0, 'name': ['SYF', -0.013325, 'FINANCIAL_SERVICES']},
#    {'value': 45300000000.0, 'name': ['UBS', 0.004234, 'FINANCIAL_SERVICES']},
#    {'value': 136000000000.0,
#     'name': ['PYPL', 0.013856, 'FINANCIAL_SERVICES']}]},
#  {'value': 3076000000000.0,
#   'name': 'HEALTHCARE',
#   'children': [{'value': 143000000000.0,
#     'name': ['ABT', 0.006442, 'HEALTHCARE']},
#    {'value': 107000000000.0, 'name': ['AMGN', 0.000342, 'HEALTHCARE']},
#    {'value': 39900000000.0,
#     'name': ['BAX', 0.007476000000000001, 'HEALTHCARE']},
#    {'value': 64800000000.0,
#     'name': ['BDX', 0.0073409999999999994, 'HEALTHCARE']},
#    {'value': 75300000000.0, 'name': ['BMY', -0.016257, 'HEALTHCARE']},
#    {'value': 57600000000.0, 'name': ['BSX', 0.004118, 'HEALTHCARE']},
#    {'value': 59400000000.0, 'name': ['CI', -0.005525, 'HEALTHCARE']},
#    {'value': 98800000000.0, 'name': ['DHR', 0.0032, 'HEALTHCARE']},
#    {'value': 84100000000.0, 'name': ['GILD', 0.011628, 'HEALTHCARE']},
#    {'value': 33700000000.0,
#     'name': ['HUM', 0.0035369999999999998, 'HEALTHCARE']},
#    {'value': 44300000000.0, 'name': ['BIIB', 0.005282, 'HEALTHCARE']},
#    {'value': 23100000000.0,
#     'name': ['IDXX', 0.013059999999999999, 'HEALTHCARE']},
#    {'value': 369000000000.0,
#     'name': ['JNJ', 0.0032479999999999996, 'HEALTHCARE']},
#    {'value': 111000000000.0, 'name': ['LLY', -0.037441, 'HEALTHCARE']},
#    {'value': 131000000000.0, 'name': ['MDT', 0.006488, 'HEALTHCARE']},
#    {'value': 71500000000.0, 'name': ['CVS', 0.020401, 'HEALTHCARE']},
#    {'value': 212000000000.0, 'name': ['MRK', 0.000121, 'HEALTHCARE']},
#    {'value': 239000000000.0, 'name': ['PFE', 0.003029, 'HEALTHCARE']},
#    {'value': 33400000000.0, 'name': ['REGN', -0.007857, 'HEALTHCARE']},
#    {'value': 73300000000.0, 'name': ['SYK', 0.009315, 'HEALTHCARE']},
#    {'value': 113000000000.0,
#     'name': ['TMO', 0.007529000000000001, 'HEALTHCARE']},
#    {'value': 236000000000.0, 'name': ['UNH', 0.005471, 'HEALTHCARE']},
#    {'value': 44300000000.0,
#     'name': ['VRTX', -0.0039770000000000005, 'HEALTHCARE']},
#    {'value': 41500000000.0, 'name': ['AGN', -0.004405, 'HEALTHCARE']},
#    {'value': 25200000000.0,
#     'name': ['MCK', 0.019188999999999998, 'HEALTHCARE']},
#    {'value': 26100000000.0, 'name': ['ALXN', -0.016981, 'HEALTHCARE']},
#    {'value': 20000000000.0, 'name': ['MTD', 0.020246, 'HEALTHCARE']},
#    {'value': 38500000000.0, 'name': ['EW', 0.007508, 'HEALTHCARE']},
#    {'value': 49600000000.0,
#     'name': ['ILMN', 0.0048590000000000005, 'HEALTHCARE']},
#    {'value': 25200000000.0, 'name': ['ALGN', 0.023866, 'HEALTHCARE']},
#    {'value': 17800000000.0, 'name': ['ABC', 0.015696, 'HEALTHCARE']},
#    {'value': 24900000000.0, 'name': ['ZBH', 0.008368, 'HEALTHCARE']},
#    {'value': 22700000000.0, 'name': ['CNC', 0.014394, 'HEALTHCARE']},
#    {'value': 22200000000.0, 'name': ['A', 0.010646, 'HEALTHCARE']},
#    {'value': 58800000000.0, 'name': ['ISRG', 0.02102, 'HEALTHCARE']},
#    {'value': 44600000000.0, 'name': ['HCA', 0.014409, 'HEALTHCARE']},
#    {'value': 114000000000.0,
#     'name': ['ABBV', -0.0061979999999999995, 'HEALTHCARE']},
#    {'value': 52800000000.0, 'name': ['ZTS', 0.00109, 'HEALTHCARE']},
#    {'value': 27600000000.0, 'name': ['IQV', 0.006919, 'HEALTHCARE']}]},
#  {'value': 2365500000000.0,
#   'name': 'INDUSTRIALS',
#   'children': [{'value': 19700000000.0,
#     'name': ['AME', 0.008981999999999999, 'INDUSTRIALS']},
#    {'value': 73000000000.0, 'name': ['ADP', 0.004493, 'INDUSTRIALS']},
#    {'value': 199000000000.0, 'name': ['BA', 0.000424, 'INDUSTRIALS']},
#    {'value': 71900000000.0,
#     'name': ['CAT', 0.010287000000000001, 'INDUSTRIALS']},
#    {'value': 32500000000.0, 'name': ['CP', -0.010867, 'INDUSTRIALS']},
#    {'value': 63700000000.0, 'name': ['CSX', 0.008201, 'INDUSTRIALS']},
#    {'value': 24500000000.0, 'name': ['CTAS', 0.008637, 'INDUSTRIALS']},
#    {'value': 25700000000.0, 'name': ['CMI', 0.00704, 'INDUSTRIALS']},
#    {'value': 47500000000.0, 'name': ['DE', 0.0076, 'INDUSTRIALS']},
#    {'value': 39700000000.0,
#     'name': ['EMR', 0.015080000000000001, 'INDUSTRIALS']},
#    {'value': 33600000000.0, 'name': ['ETN', 0.002908, 'INDUSTRIALS']},
#    {'value': 18700000000.0,
#     'name': ['FAST', 0.011779000000000001, 'INDUSTRIALS']},
#    {'value': 42200000000.0, 'name': ['FDX', 0.024045, 'INDUSTRIALS']},
#    {'value': 35500000000.0, 'name': ['FISV', 0.00936, 'INDUSTRIALS']},
#    {'value': 50100000000.0,
#     'name': ['GD', -0.0035060000000000004, 'INDUSTRIALS']},
#    {'value': 87600000000.0, 'name': ['GE', 0.007014, 'INDUSTRIALS']},
#    {'value': 30200000000.0, 'name': ['IR', -0.000239, 'INDUSTRIALS']},
#    {'value': 49600000000.0,
#     'name': ['ITW', 0.0068790000000000006, 'INDUSTRIALS']},
#    {'value': 27300000000.0, 'name': ['LUV', -0.00139, 'INDUSTRIALS']},
#    {'value': 97000000000.0, 'name': ['MMM', 0.009963, 'INDUSTRIALS']},
#    {'value': 52900000000.0,
#     'name': ['NOC', -0.022116999999999998, 'INDUSTRIALS']},
#    {'value': 53600000000.0, 'name': ['NSC', -0.008128, 'INDUSTRIALS']},
#    {'value': 31600000000.0, 'name': ['PAYX', 0.002283, 'INDUSTRIALS']},
#    {'value': 24300000000.0, 'name': ['PCAR', -0.000285, 'INDUSTRIALS']},
#    {'value': 21400000000.0, 'name': ['PH', 0.007552, 'INDUSTRIALS']},
#    {'value': 18800000000.0, 'name': ['ROK', 0.010951, 'INDUSTRIALS']},
#    {'value': 38100000000.0, 'name': ['ROP', 0.005035, 'INDUSTRIALS']},
#    {'value': 52400000000.0,
#     'name': ['RTN', 0.006562999999999999, 'INDUSTRIALS']},
#    {'value': 21100000000.0,
#     'name': ['SWK', 0.013071000000000001, 'INDUSTRIALS']},
#    {'value': 34900000000.0, 'name': ['JCI', -0.007417, 'INDUSTRIALS']},
#    {'value': 122000000000.0,
#     'name': ['UNP', 0.0029100000000000003, 'INDUSTRIALS']},
#    {'value': 110000000000.0,
#     'name': ['UTX', -0.031107999999999997, 'INDUSTRIALS']},
#    {'value': 99300000000.0, 'name': ['LMT', -0.010277, 'INDUSTRIALS']},
#    {'value': 65200000000.0, 'name': ['CNI', -0.00877, 'INDUSTRIALS']},
#    {'value': 20200000000.0,
#     'name': ['LLL', -0.0072569999999999996, 'INDUSTRIALS']},
#    {'value': 27800000000.0, 'name': ['RSG', -0.002535, 'INDUSTRIALS']},
#    {'value': 48300000000.0,
#     'name': ['WM', -0.004372999999999999, 'INDUSTRIALS']},
#    {'value': 86200000000.0, 'name': ['UPS', 0.019456, 'INDUSTRIALS']},
#    {'value': 25100000000.0, 'name': ['GPN', -0.002983, 'INDUSTRIALS']},
#    {'value': 39600000000.0, 'name': ['FIS', -0.001877, 'INDUSTRIALS']},
#    {'value': 125000000000.0,
#     'name': ['HON', -0.0061530000000000005, 'INDUSTRIALS']},
#    {'value': 21800000000.0, 'name': ['UAL', -0.007325, 'INDUSTRIALS']},
#    {'value': 25200000000.0,
#     'name': ['TDG', 0.012740000000000001, 'INDUSTRIALS']},
#    {'value': 35800000000.0, 'name': ['DAL', -0.006465, 'INDUSTRIALS']},
#    {'value': 24700000000.0, 'name': ['WCN', -0.002663, 'INDUSTRIALS']},
#    {'value': 24000000000.0, 'name': ['VRSK', 0.002867, 'INDUSTRIALS']},
#    {'value': 22900000000.0, 'name': ['FLT', 0.027788, 'INDUSTRIALS']},
#    {'value': 24300000000.0, 'name': ['INFO', 0.019637, 'INDUSTRIALS']}]},
#  {'value': 505300000000.0,
#   'name': 'REAL_ESTATE',
#   'children': [{'value': 33400000000.0,
#     'name': ['WELL', -0.010570999999999999, 'REAL_ESTATE']},
#    {'value': 18000000000.0,
#     'name': ['WY', 0.013031000000000001, 'REAL_ESTATE']},
#    {'value': 28800000000.0, 'name': ['EQR', -0.001796, 'REAL_ESTATE']},
#    {'value': 49900000000.0, 'name': ['SPG', -0.012118, 'REAL_ESTATE']},
#    {'value': 19500000000.0, 'name': ['ESS', -0.002427, 'REAL_ESTATE']},
#    {'value': 22700000000.0, 'name': ['O', -0.012385, 'REAL_ESTATE']},
#    {'value': 20800000000.0, 'name': ['BXP', -0.01153, 'REAL_ESTATE']},
#    {'value': 23000000000.0, 'name': ['VTR', -0.005418, 'REAL_ESTATE']},
#    {'value': 29200000000.0,
#     'name': ['AVB', 0.0014349999999999999, 'REAL_ESTATE']},
#    {'value': 56000000000.0, 'name': ['CCI', -0.004067, 'REAL_ESTATE']},
#    {'value': 25100000000.0, 'name': ['SBAC', 0.005194, 'REAL_ESTATE']},
#    {'value': 20100000000.0, 'name': ['CSGP', 0.019875, 'REAL_ESTATE']},
#    {'value': 42500000000.0, 'name': ['EQIX', 0.012852, 'REAL_ESTATE']},
#    {'value': 49500000000.0, 'name': ['PLD', 0.002558, 'REAL_ESTATE']},
#    {'value': 42500000000.0, 'name': ['PSA', -0.006442, 'REAL_ESTATE']},
#    {'value': 24300000000.0,
#     'name': ['DLR', 0.0071519999999999995, 'REAL_ESTATE']}]},
#  {'value': 5941700000000.0,
#   'name': 'TECHNOLOGY',
#   'children': [{'value': 886000000000.0,
#     'name': ['AAPL', 0.012412000000000001, 'TECHNOLOGY']},
#    {'value': 36300000000.0,
#     'name': ['ADSK', -0.0010890000000000001, 'TECHNOLOGY']},
#    {'value': 137000000000.0, 'name': ['ADBE', 0.00773, 'TECHNOLOGY']},
#    {'value': 39400000000.0, 'name': ['ADI', 0.058298, 'TECHNOLOGY']},
#    {'value': 40400000000.0,
#     'name': ['AMAT', 0.039758999999999996, 'TECHNOLOGY']},
#    {'value': 35900000000.0, 'name': ['AMD', 0.025301, 'TECHNOLOGY']},
#    {'value': 28100000000.0, 'name': ['APH', 0.010735, 'TECHNOLOGY']},
#    {'value': 18900000000.0, 'name': ['CDNS', 0.024405, 'TECHNOLOGY']},
#    {'value': 23700000000.0, 'name': ['CERN', -0.000412, 'TECHNOLOGY']},
#    {'value': 242000000000.0, 'name': ['CSCO', 0.008402, 'TECHNOLOGY']},
#    {'value': 28400000000.0, 'name': ['EA', -0.015055, 'TECHNOLOGY']},
#    {'value': 20700000000.0, 'name': ['GIB', -0.00106, 'TECHNOLOGY']},
#    {'value': 24300000000.0, 'name': ['GLW', 0.012133, 'TECHNOLOGY']},
#    {'value': 23200000000.0,
#     'name': ['HRS', -0.008223999999999999, 'TECHNOLOGY']},
#    {'value': 29900000000.0, 'name': ['HPQ', 0.009645, 'TECHNOLOGY']},
#    {'value': 119000000000.0, 'name': ['IBM', 0.010653, 'TECHNOLOGY']},
#    {'value': 210000000000.0, 'name': ['INTC', 0.016728, 'TECHNOLOGY']},
#    {'value': 18300000000.0, 'name': ['KLAC', 0.036445, 'TECHNOLOGY']},
#    {'value': 28700000000.0, 'name': ['LRCX', 0.024162, 'TECHNOLOGY']},
#    {'value': 26600000000.0, 'name': ['MSI', -0.012654, 'TECHNOLOGY']},
#    {'value': 1020000000000.0, 'name': ['MSFT', 0.009132, 'TECHNOLOGY']},
#    {'value': 38700000000.0, 'name': ['MU', 0.028546, 'TECHNOLOGY']},
#    {'value': 185000000000.0, 'name': ['ORCL', 0.014085, 'TECHNOLOGY']},
#    {'value': 85800000000.0,
#     'name': ['QCOM', 0.027077999999999998, 'TECHNOLOGY']},
#    {'value': 18900000000.0, 'name': ['SNPS', 0.018392, 'TECHNOLOGY']},
#    {'value': 106000000000.0,
#     'name': ['TXN', 0.012950999999999999, 'TECHNOLOGY']},
#    {'value': 28200000000.0, 'name': ['XLNX', 0.031544, 'TECHNOLOGY']},
#    {'value': 67500000000.0, 'name': ['INTU', 0.011866, 'TECHNOLOGY']},
#    {'value': 20400000000.0,
#     'name': ['MCHP', 0.025588999999999997, 'TECHNOLOGY']},
#    {'value': 35200000000.0,
#     'name': ['ATVI', 0.013550999999999999, 'TECHNOLOGY']},
#    {'value': 17700000000.0, 'name': ['CHKP', 0.018487, 'TECHNOLOGY']},
#    {'value': 24700000000.0, 'name': ['VRSN', -0.000193, 'TECHNOLOGY']},
#    {'value': 35900000000.0,
#     'name': ['CTSH', 0.0039030000000000002, 'TECHNOLOGY']},
#    {'value': 90400000000.0, 'name': ['NVDA', 0.020275, 'TECHNOLOGY']},
#    {'value': 118000000000.0, 'name': ['ACN', 0.00787, 'TECHNOLOGY']},
#    {'value': 119000000000.0,
#     'name': ['CRM', -0.052226999999999996, 'TECHNOLOGY']},
#    {'value': 19300000000.0,
#     'name': ['IAC', 0.0031550000000000003, 'TECHNOLOGY']},
#    {'value': 751000000000.0,
#     'name': ['GOOGL', 0.012768999999999999, 'TECHNOLOGY']},
#    {'value': 30900000000.0, 'name': ['TEL', 0.00605, 'TECHNOLOGY']},
#    {'value': 70600000000.0, 'name': ['VMW', 0.016365, 'TECHNOLOGY']},
#    {'value': 111000000000.0, 'name': ['AVGO', 0.019464, 'TECHNOLOGY']},
#    {'value': 17800000000.0, 'name': ['SPLK', 0.064583, 'TECHNOLOGY']},
#    {'value': 499000000000.0, 'name': ['FB', 0.008596, 'TECHNOLOGY']},
#    {'value': 51200000000.0, 'name': ['NOW', 0.004734, 'TECHNOLOGY']},
#    {'value': 19100000000.0, 'name': ['PANW', 0.01762, 'TECHNOLOGY']},
#    {'value': 48300000000.0, 'name': ['WDAY', 0.010734, 'TECHNOLOGY']},
#    {'value': 23900000000.0, 'name': ['VEEV', 0.002344, 'TECHNOLOGY']},
#    {'value': 28900000000.0,
#     'name': ['TWTR', -0.007906999999999999, 'TECHNOLOGY']},
#    {'value': 19200000000.0, 'name': ['ANET', 0.015019, 'TECHNOLOGY']},
#    {'value': 34300000000.0, 'name': ['SHOP', 0.005507, 'TECHNOLOGY']},
#    {'value': 19100000000.0, 'name': ['HPE', 0.011356, 'TECHNOLOGY']},
#    {'value': 19800000000.0, 'name': ['MTCH', -0.008877, 'TECHNOLOGY']},
#    {'value': 29800000000.0, 'name': ['SQ', 0.02805, 'TECHNOLOGY']},
#    {'value': 32100000000.0, 'name': ['TEAM', 0.010718, 'TECHNOLOGY']},
#    {'value': 26400000000.0, 'name': ['FTV', -0.000127, 'TECHNOLOGY']},
#    {'value': 18100000000.0, 'name': ['TWLO', -0.003747, 'TECHNOLOGY']},
#    {'value': 18500000000.0, 'name': ['SNAP', -0.008142, 'TECHNOLOGY']},
#    {'value': 25200000000.0,
#     'name': ['SPOT', -0.0059960000000000005, 'TECHNOLOGY']}]},
#  {'value': 693100000000.0,
#   'name': 'UTILITIES',
#   'children': [{'value': 43900000000.0,
#     'name': ['AEP', -0.005807, 'UTILITIES']},
#    {'value': 60500000000.0, 'name': ['D', -0.00554, 'UTILITIES']},
#    {'value': 23500000000.0,
#     'name': ['DTE', -0.0022559999999999998, 'UTILITIES']},
#    {'value': 62800000000.0, 'name': ['DUK', -0.009075, 'UTILITIES']},
#    {'value': 28500000000.0, 'name': ['ED', -0.012118, 'UTILITIES']},
#    {'value': 19800000000.0, 'name': ['ETR', -0.007058, 'UTILITIES']},
#    {'value': 97400000000.0, 'name': ['NEE', -0.005039, 'UTILITIES']},
#    {'value': 24100000000.0,
#     'name': ['ES', -0.0039310000000000005, 'UTILITIES']},
#    {'value': 30300000000.0, 'name': ['PEG', -0.002666, 'UTILITIES']},
#    {'value': 22200000000.0, 'name': ['PPL', -0.010316, 'UTILITIES']},
#    {'value': 56700000000.0, 'name': ['SO', -0.004569, 'UTILITIES']},
#    {'value': 26100000000.0, 'name': ['WEC', -0.002893, 'UTILITIES']},
#    {'value': 19800000000.0,
#     'name': ['EIX', -0.028114999999999998, 'UTILITIES']},
#    {'value': 22900000000.0,
#     'name': ['FE', -0.00023199999999999997, 'UTILITIES']},
#    {'value': 30500000000.0,
#     'name': ['XEL', -0.0030280000000000003, 'UTILITIES']},
#    {'value': 48100000000.0,
#     'name': ['EXC', -0.008206999999999999, 'UTILITIES']},
#    {'value': 36800000000.0,
#     'name': ['SRE', -0.0030489999999999996, 'UTILITIES']},
#    {'value': 18600000000.0, 'name': ['AEE', 0.000132, 'UTILITIES']},
#    {'value': 20600000000.0, 'name': ['AWK', -0.003956, 'UTILITIES']}]}]

# %%
label_formatter = """function (params) {
        sign = (params.name[1] > 0) ? '+' : '';
        return params.name[0] + '\\n' + sign + window.parseFloat(params.name[1]*100).toFixed(2) + '%'
    }"""

# %%
tooltip_formatter = """function (params) {
up_down_flat = (params.name[1] > 0) ? '涨' : (params.name[1] < 0) ? '跌' : '平';
return params.name[0] + '<br>' + '行业: ' + params.name[2]  + 
        '<br>' + '市值: ' + window.parseFloat(params.value/100000000) + ' 亿美元' +
        '<br>' + '涨跌: ' + up_down_flat;
    }"""

# %%
treemap = (
    TreeMap( init_opts=opts.InitOpts(width="1000px", height="600px") )
    .add("", 
         data_for_treemap,
         label_opts=opts.LabelOpts(position="inside", font_size=10, formatter=JsCode(label_formatter)),
         tooltip_opts=opts.TooltipOpts(formatter=JsCode(tooltip_formatter)),
        )
    .set_global_opts(title_opts=opts.TitleOpts(title="美股树形图"))
)

treemap.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2444a8b41a224a7f8a3bf8b883666da3" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2444a8b41a224a7f8a3bf8b883666da3 = echarts.init(
#                     document.getElementById('2444a8b41a224a7f8a3bf8b883666da3'), 'white', {renderer: 'canvas'});
#                 var option_2444a8b41a224a7f8a3bf8b883666da3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "treemap",
#             "data": [
#                 {
#                     "value": 336700000000.0,
#                     "name": "BASIC_MATERIALS",
#                     "children": [
#                         {
#                             "value": 23600000000.0,
#                             "name": [
#                                 "GOLD",
#                                 -0.006642,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 48700000000.0,
#                             "name": [
#                                 "APD",
#                                 -0.00731,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 57600000000.0,
#                             "name": [
#                                 "ECL",
#                                 0.004327,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 28900000000.0,
#                             "name": [
#                                 "NEM",
#                                 -0.011208,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 27000000000.0,
#                             "name": [
#                                 "PPG",
#                                 0.00307,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 43500000000.0,
#                             "name": [
#                                 "SHW",
#                                 -0.004979,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 17900000000.0,
#                             "name": [
#                                 "VMC",
#                                 0.009007,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 28100000000.0,
#                             "name": [
#                                 "SCCO",
#                                 0.009154,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 31000000000.0,
#                             "name": [
#                                 "LYB",
#                                 0.056313,
#                                 "BASIC_MATERIALS"
#                             ]
#                         },
#                         {
#                             "value": 30400000000.0,
#                             "name": [
#                                 "NTR",
#                                 0.004647,
#                                 "BASIC_MATERIALS"
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "value": 1067600000000.0,
#                     "name": "COMMUNICATION_SERVICES",
#                     "children": [
#                         {
#                             "value": 42100000000.0,
#                             "name": [
#                                 "BCE",
#                                 -0.001067,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 187000000000.0,
#                             "name": [
#                                 "CMCSA",
#                                 -0.004099,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 233000000000.0,
#                             "name": [
#                                 "T",
#                                 -0.017549000000000002,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 17500000000.0,
#                             "name": [
#                                 "DISH",
#                                 0.005925,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 27400000000.0,
#                             "name": [
#                                 "RCI",
#                                 0.0,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 232000000000.0,
#                             "name": [
#                                 "VZ",
#                                 -0.018703,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 22700000000.0,
#                             "name": [
#                                 "TU",
#                                 0.002654,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 92800000000.0,
#                             "name": [
#                                 "AMT",
#                                 -0.012145999999999999,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 19300000000.0,
#                             "name": [
#                                 "LBTYK",
#                                 0.016797,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 65500000000.0,
#                             "name": [
#                                 "TMUS",
#                                 -0.0042829999999999995,
#                                 "COMMUNICATION_SERVICES"
#                             ]
#                         },
#                         {
#                             "value": 88300000000.0,

# %% [markdown]
# ---
# ### 总结
#
# 生成直角坐标系的单图对象的代码通常如下：
#
# 	obj = ( Object(...).add_xaxis(...)
#                        .add_yaxis(...)
#         	 	      .set_global_options(...) )
#
# 其中 `Object` 是直角坐标系中的常见元件，如 `Kline`, `Line` 和 `Bar` 等等,省略号 ... 代表各种配置。
#
#
# 生成非直角坐标系的单图对象的代码通常如下：
#
# 	obj = ( Object(...).add(...)
#         	 	      .set_global_options(...) )
#
# 其中 `Object` 是非直角坐标系中的常见元件，如 `Pie`, `WordCount` 和 `TreeMap` 等等，省略号 ... 代表各种配置。
#
# 图对象生成后，显示它有两种方式：
#
# 	obj.render_notebook()	在 Jupyter Notebook 中显示
# 	obj.render('xxx.html')  在网页中显示

# %% [markdown]
# # <font color='#dc2624' face='微软雅黑'>4. 多图</font><a name='4'></a>
# [<font color='black' face='微软雅黑'>回到目录</font>](#toc)
#
# **`PyEcharts`** 中的多图有四种，并行图 (grid)、时间轮播图 (timeline)、选项卡图 (tab) 和页面图 (page)。
#
# ### <font color='#2b4750' face='微软雅黑'>4.1 并行图</font><a name='4.1'></a>
# [<font color='black' face='微软雅黑'>回到章首</font>](#4)
#
# 用苹果股票、标准普尔 500 指数 (SPX) 和恐慌指数 (VIX) 数据举例，画出同一时段内的股票 K 线图和指数折线图。

# %%
stock_data = pd.read_csv( '1Y Stock Data.csv', parse_dates=[0], dayfirst=True )
stock_data.head().append(stock_data.tail())
# Out:
#            Date Symbol        Open        High         Low       Close  \
# 0    2018-02-26   AAPL  176.350006  179.389999  176.210007  178.970001
# 1    2018-02-27   AAPL  179.100006  180.479996  178.160004  178.389999
# 2    2018-02-28   AAPL  179.259995  180.619995  178.050003  178.119995
# 3    2018-03-01   AAPL  178.539993  179.779999  172.660004  175.000000
# 4    2018-03-02   AAPL  172.800003  176.300003  172.449997  176.210007
# 1255 2019-02-20     GS  198.729996  199.300003  197.509995  198.600006
# 1256 2019-02-21     GS  198.970001  199.449997  195.050003  196.360001
# 1257 2019-02-22     GS  196.600006  197.750000  195.199997  196.000000
# 1258 2019-02-25     GS  198.000000  201.500000  197.710007  198.649994
# 1259 2019-02-26     GS  198.470001  200.559998  196.550003  198.899994
#
#        Adj Close    Volume
# 0     176.285675  38162200
# 1     175.714386  38928100
# 2     175.448410  37782100
# 3     172.375214  48802000
# 4     173.567078  38454000
# 1255  198.600006   2266000
# 1256  196.360001   2785900
# 1257  196.000000   2626600
# 1258  198.649994   3032200
# 1259  198.899994   2498000

# %%
data = pd.read_csv( 'S&P500.csv', index_col=0, parse_dates=True, dayfirst=True )
spx = data[['Adj Close']].loc['2018-02-26':'2019-02-26']
spx.head(3).append(spx.tail(3))
# Out:
#               Adj Close
# Date
# 2018-02-26  2779.600098
# 2018-02-27  2744.280029
# 2018-02-28  2713.830078
# 2019-02-22  2792.669922
# 2019-02-25  2796.110107
# 2019-02-26  2793.899902

# %%
data = pd.read_csv( 'VIX.csv', index_col=0, parse_dates=True, dayfirst=True )
vix = data[['Adj Close']].loc['2018-02-26':'2019-02-26']
vix.head(3).append(vix.tail(3))
# Out:
#             Adj Close
# Date
# 2018-02-26      15.80
# 2018-02-27      18.59
# 2018-02-28      19.85
# 2019-02-22      13.51
# 2019-02-25      14.85
# 2019-02-26      15.17

# %%
code = 'AAPL'
stock = stock_data[ stock_data['Symbol']==code ]

date = stock['Date'].dt.strftime('%d-%b-%Y').tolist()
price = stock[['Open','Close','Low','High']].values.tolist()

kline = (
    Kline()
    .add_xaxis(date)
    .add_yaxis('', price)
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, 
                areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        xaxis_opts=opts.AxisOpts(is_scale=True),
        title_opts=opts.TitleOpts(title=code, pos_top='25%'),
        datazoom_opts=[opts.DataZoomOpts(type_='slider',
                                         xaxis_index=[0, 1, 2],
                                         range_start=0,
                                         range_end=len(date),),
                       opts.DataZoomOpts(type_='inside',
                                         xaxis_index=[0, 1, 2],
                                         range_start=0,
                                         range_end=len(date),)],
    )
)

line1 = (
    Line()
    .add_xaxis(date)
    .add_yaxis(
            series_name='',
            y_axis=spx.values.tolist(),
            markpoint_opts=opts.MarkPointOpts(
                data=[opts.MarkPointItem(type_='min')]),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=3, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(is_scale=True),
        title_opts=opts.TitleOpts(title='SPX', pos_top='55%'),
    )
)

line2 = (
    Line()
    .add_xaxis(date)
    .add_yaxis(
            series_name='',
            y_axis=vix.values.tolist(),
            markpoint_opts=opts.MarkPointOpts(
                data=[opts.MarkPointItem(type_='max')]),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=3, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_scale=True),
        yaxis_opts=opts.AxisOpts(is_scale=True),
        title_opts=opts.TitleOpts(title='VIX', pos_top='75%'),
    )
)

grid_chart = Grid( init_opts=opts.InitOpts(width="1000px", height="600px") )

grid_chart.add(
    kline,
    grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", pos_top="5%", height="40%")
)
grid_chart.add(
    line1,
    grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", pos_top="50%", height="15%")
)
grid_chart.add(
    line2,
    grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", pos_top="70%", height="15%")
)

grid_chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ebf93acd5d3748cc9bd5ba32a2116549" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ebf93acd5d3748cc9bd5ba32a2116549 = echarts.init(
#                     document.getElementById('ebf93acd5d3748cc9bd5ba32a2116549'), 'white', {renderer: 'canvas'});
#                 var option_ebf93acd5d3748cc9bd5ba32a2116549 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 [
#                     176.350006,
#                     178.970001,
#                     176.21000700000002,
#                     179.389999
#                 ],
#                 [
#                     179.100006,
#                     178.389999,
#                     178.16000400000001,
#                     180.479996
#                 ],
#                 [
#                     179.259995,
#                     178.119995,
#                     178.050003,
#                     180.619995
#                 ],
#                 [
#                     178.53999299999998,
#                     175.0,
#                     172.66000400000001,
#                     179.779999
#                 ],
#                 [
#                     172.800003,
#                     176.21000700000002,
#                     172.449997,
#                     176.300003
#                 ],
#                 [
#                     175.21000700000002,
#                     176.820007,
#                     174.520004,
#                     177.740005
#                 ],
#                 [
#                     177.91000400000001,
#                     176.669998,
#                     176.130005,
#                     178.25
#                 ],
#                 [
#                     174.940002,
#                     175.029999,
#                     174.270004,
#                     175.850006
#                 ],
#                 [
#                     175.479996,
#                     176.940002,
#                     175.070007,
#                     177.119995
#                 ],
#                 [
#                     177.96000700000002,
#                     179.979996,
#                     177.389999,
#                     180.0
#                 ],
#                 [
#                     180.28999299999998,
#                     181.720001,
#                     180.21000700000002,
#                     182.389999
#                 ],
#                 [
#                     182.58999599999999,
#                     179.970001,
#                     179.240005,
#                     183.5
#                 ],
#                 [
#                     180.320007,
#                     178.440002,
#                     177.809998,
#                     180.520004
#                 ],
#                 [
#                     178.5,
#                     178.649994,
#                     178.070007,
#                     180.240005
#                 ],
#                 [
#                     178.649994,
#                     178.020004,
#                     177.619995,
#                     179.119995
#                 ],
#                 [
#                     177.320007,
#                     175.300003,
#                     173.66000400000001,
#                     177.470001
#                 ],
#                 [
#                     175.240005,
#                     175.240005,
#                     174.940002,
#                     176.800003
#                 ],
#                 [
#                     175.03999299999998,
#                     171.270004,
#                     171.259995,
#                     175.08999599999999
#                 ],
#                 [
#                     170.0,
#                     168.850006,
#                     168.600006,
#                     172.679993
#                 ],
#                 [
#                     168.389999,
#                     164.940002,
#                     164.940002,
#                     169.919998
#                 ],
#                 [
#                     168.070007,
#                     172.770004,
#                     166.440002,
#                     173.100006
#                 ],
#                 [
#                     173.679993,
#                     168.33999599999999,
#                     166.919998,
#                     175.149994
#                 ],
#                 [
#                     167.25,
#                     166.479996,
#                     165.190002,
#                     170.020004
#                 ],
#                 [
#                     167.809998,
#                     167.779999,
#                     166.899994,
#                     171.75
#                 ],
#                 [
#                     166.639999,
#                     166.679993,
#                     164.470001,
#                     168.940002
#                 ],
#                 [
#                     167.639999,
#                     168.389999,
#                     164.880005,
#                     168.75
#                 ],
#                 [
#                     164.880005,
#                     171.610001,
#                     164.770004,
#                     172.009995
#                 ],
#                 [
#                     172.580002,
#                     172.800003,
#                     172.080002,
#                     174.229996
#                 ],
#                 [
#                     170.970001,
#                     168.380005,
#                     168.199997,
#                     172.479996
#                 ],
#                 [
#                     169.880005,
#                     170.050003,
#                     169.850006,
#                     173.08999599999999
#                 ],
#                 [
#                     173.0,
#                     173.25,
#                     171.529999,
#                     174.0
#                 ],
#                 [
#                     172.229996,
#                     172.440002,
#                     171.699997,
#                     173.919998
#                 ],
#                 [
#                     173.41000400000001,
#                     174.139999,
#                     173.03999299999998,
#                     175.0
#                 ],
#                 [
#                     174.779999,
#                     174.729996,
#                     173.850006,
#                     175.83999599999999
#                 ],
#                 [
#                     175.029999,
#                     175.820007,
#                     174.830002,
#                     176.190002
#                 ],
#                 [
#                     176.490005,
#                     178.240005,
#                     176.41000400000001,
#                     178.940002
#                 ],
#                 [
#                     177.809998,
#                     177.83999599999999,
#                     176.880005,
#                     178.820007
#                 ],
#                 [
#                     173.759995,
#                     172.800003,
#                     172.66000400000001,
#                     175.389999
#                 ],
#                 [
#                     170.600006,
#                     165.720001,
#                     165.429993,
#                     171.220001
#                 ],
#                 [
#                     166.830002,

# %% [markdown]
# 再看一个更酷的例子，模仿炒股软件画出 K 线图和交易量柱状图。在本例中使用标准普尔 500 指数 (SPX) 在 2018-02-26 到 2019-02-26 的数据。

# %%
data = pd.read_csv( 'S&P500.csv', index_col=0, parse_dates=True, dayfirst=True )
data = data.loc['2018-02-26':'2019-02-26']
data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-02-26  2757.370117  2780.639893  2753.780029  2779.600098  2779.600098
# 2018-02-27  2780.449951  2789.149902  2744.219971  2744.280029  2744.280029
# 2018-02-28  2753.780029  2761.520020  2713.540039  2713.830078  2713.830078
# 2018-03-01  2715.219971  2730.889893  2659.649902  2677.669922  2677.669922
# 2018-03-02  2658.889893  2696.250000  2647.320068  2691.250000  2691.250000
#
#                 Volume
# Date
# 2018-02-26  3424650000
# 2018-02-27  3745080000
# 2018-02-28  4230660000
# 2018-03-01  4503970000
# 2018-03-02  3882450000

# %%
date = pd.to_datetime(data.index).strftime('%Y/%m/%d').tolist()
price = data[['Open','Close','Low','High']].values.tolist()
close = data['Close']
volume = data['Volume'].values.tolist()

# %%
kline = (
    Kline()
    .add_xaxis(xaxis_data=date)
    .add_yaxis(
        series_name="S&P index",
        y_axis=price,
        itemstyle_opts=opts.ItemStyleOpts(color="#ec0000", color0="#00da3c", 
                                          border_color="#ec0000", border_color0="#00da3c"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="标普 500 指数",
            subtitle="MA5, MA20",
        ),
        xaxis_opts=opts.AxisOpts(type_="category"),
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
        datazoom_opts=[
            opts.DataZoomOpts(
                is_show=False,
                type_="inside",
                xaxis_index=[0, 1],
                range_start=0,
                range_end=100,
            ),
            opts.DataZoomOpts(
                is_show=True,
                xaxis_index=[0, 1],
                type_="slider",
                pos_top="90%",
                range_start=0,
                range_end=100,
            ),
        ],
        tooltip_opts=opts.TooltipOpts(
            trigger="axis",
            axis_pointer_type="cross",
            background_color="rgba(245, 245, 245, 0.8)",
            border_width=1,
            border_color="#ccc",
            textstyle_opts=opts.TextStyleOpts(color="#000", font_size=10),
        ),
        visualmap_opts=opts.VisualMapOpts(
            is_show=False,
            dimension=2,
            series_index=3,
            is_piecewise=True,
            pieces=[
                {"value": -1, "color": "#ec0000"},
                {"value": 1, "color": "#00da3c"},
            ],
        ),
        axispointer_opts=opts.AxisPointerOpts(
            is_show=True,
            link=[{"xAxisIndex": "all"}],
            label=opts.LabelOpts(background_color="#777"),
        ),
        brush_opts=opts.BrushOpts(
            x_axis_index="all",
            brush_link="all",
            out_of_brush={"colorAlpha": 0.1},
            brush_type="lineX",
            brush_style = {"borderWidth": 1, "color":"rgba(120,140,180,0.3)", "borderColor":"black"},
        ),
    )
)

line = (
    Line()
    .add_xaxis(xaxis_data=date)
    .add_yaxis(
        series_name="MA5",
        y_axis=close.rolling(5).mean().tolist(),
        is_smooth=True,
        is_hover_animation=False,
        linestyle_opts=opts.LineStyleOpts(width=2, opacity=0.5),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="MA20",
        y_axis=close.rolling(20).mean().tolist(),
        is_smooth=True,
        is_hover_animation=False,
        linestyle_opts=opts.LineStyleOpts(width=2, opacity=0.5),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(xaxis_opts=opts.AxisOpts(type_="category"))
    )

bar = (
    Bar()
    .add_xaxis(xaxis_data=date)
    .add_yaxis(
        series_name="Volume",
        y_axis=[
            [i, volume[i], 1 if price[i][0] > price[i][1] else -1]
            for i in range(len(data))
        ],
        xaxis_index=1,
        yaxis_index=1,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="category",
            is_scale=True,
            grid_index=1,
            boundary_gap=False,
            axisline_opts=opts.AxisLineOpts(is_on_zero=False),
            axistick_opts=opts.AxisTickOpts(is_show=False),
            splitline_opts=opts.SplitLineOpts(is_show=False),
            axislabel_opts=opts.LabelOpts(is_show=False),
            split_number=20,
            min_="dataMin",
            max_="dataMax",
        ),
        yaxis_opts=opts.AxisOpts(
            grid_index=1,
            is_scale=True,
            split_number=2,
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)

# Kline And Line
overlap_kline_line = kline.overlap(line)

# Grid Overlap + Bar
grid_chart = Grid( init_opts=opts.InitOpts(width="1000px", height="600px") )

grid_chart.add(
    overlap_kline_line,
    grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", height="50%")
    )
grid_chart.add(
    bar,
    grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", pos_top="70%", height="16%")
)

grid_chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="31f61c62d256498f89ee1c1ec6219e74" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_31f61c62d256498f89ee1c1ec6219e74 = echarts.init(
#                     document.getElementById('31f61c62d256498f89ee1c1ec6219e74'), 'white', {renderer: 'canvas'});
#                 var option_31f61c62d256498f89ee1c1ec6219e74 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "S&P index",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 [
#                     2757.3701170000004,
#                     2779.600098,
#                     2753.780029,
#                     2780.639893
#                 ],
#                 [
#                     2780.449951,
#                     2744.280029,
#                     2744.219971,
#                     2789.149902
#                 ],
#                 [
#                     2753.780029,
#                     2713.830078,
#                     2713.540039,
#                     2761.52002
#                 ],
#                 [
#                     2715.219971,
#                     2677.669922,
#                     2659.649902,
#                     2730.889893
#                 ],
#                 [
#                     2658.889893,
#                     2691.25,
#                     2647.320068,
#                     2696.25
#                 ],
#                 [
#                     2681.060059,
#                     2720.939941,
#                     2675.75,
#                     2728.090088
#                 ],
#                 [
#                     2730.179932,
#                     2728.1201170000004,
#                     2711.26001,
#                     2732.080078
#                 ],
#                 [
#                     2710.179932,
#                     2726.800049,
#                     2701.73999,
#                     2730.600098
#                 ],
#                 [
#                     2732.75,
#                     2738.969971,
#                     2722.649902,
#                     2740.449951
#                 ],
#                 [
#                     2752.909912,
#                     2786.570068,
#                     2751.540039,
#                     2786.570068
#                 ],
#                 [
#                     2790.540039,
#                     2783.02002,
#                     2779.26001,
#                     2796.97998
#                 ],
#                 [
#                     2792.310059,
#                     2765.310059,
#                     2758.679932,
#                     2801.899902
#                 ],
#                 [
#                     2774.060059,
#                     2749.47998,
#                     2744.3798829999996,
#                     2777.110107
#                 ],
#                 [
#                     2754.27002,
#                     2747.330078,
#                     2741.469971,
#                     2763.030029
#                 ],
#                 [
#                     2750.570068,
#                     2752.01001,
#                     2749.969971,
#                     2761.850098
#                 ],
#                 [
#                     2741.3798829999996,
#                     2712.919922,
#                     2694.590088,
#                     2741.3798829999996
#                 ],
#                 [
#                     2715.050049,
#                     2716.939941,
#                     2710.050049,
#                     2724.219971
#                 ],
#                 [
#                     2714.98999,
#                     2711.929932,
#                     2709.790039,
#                     2739.139893
#                 ],
#                 [
#                     2691.360107,
#                     2643.689941,
#                     2641.590088,
#                     2695.679932
#                 ],
#                 [
#                     2646.709961,
#                     2588.26001,
#                     2585.889893,
#                     2657.669922
#                 ],
#                 [
#                     2619.350098,
#                     2658.550049,
#                     2601.810059,
#                     2661.360107
#                 ],
#                 [
#                     2667.570068,
#                     2612.6201170000004,
#                     2596.1201170000004,
#                     2674.780029
#                 ],
#                 [
#                     2611.300049,
#                     2605.0,
#                     2593.060059,
#                     2632.649902
#                 ],
#                 [
#                     2614.409912,
#                     2640.8701170000004,
#                     2609.719971,
#                     2659.070068
#                 ],
#                 [
#                     2633.449951,
#                     2581.8798829999996,
#                     2553.800049,
#                     2638.300049
#                 ],
#                 [
#                     2592.169922,
#                     2614.449951,
#                     2575.48999,
#                     2619.139893
#                 ],
#                 [
#                     2584.040039,
#                     2644.689941,
#                     2573.610107,
#                     2649.860107
#                 ],
#                 [
#                     2657.360107,
#                     2662.840088,
#                     2649.580078,
#                     2672.080078
#                 ],
#                 [
#                     2645.820068,
#                     2604.469971,
#                     2586.27002,
#                     2656.8798829999996
#                 ],
#                 [
#                     2617.179932,
#                     2613.159912,
#                     2610.790039,
#                     2653.550049
#                 ],
#                 [
#                     2638.409912,
#                     2656.8701170000004,
#                     2635.780029,
#                     2665.449951
#                 ],
#                 [
#                     2643.889893,
#                     2642.189941,
#                     2639.25,
#                     2661.429932
#                 ],
#                 [
#                     2653.830078,
#                     2663.98999,
#                     2653.830078,
#                     2674.719971
#                 ],
#                 [
#                     2676.899902,
#                     2656.300049,
#                     2645.050049,
#                     2680.26001
#                 ],
#                 [
#                     2670.100098,
#                     2677.840088,
#                     2665.159912,
#                     2686.48999
#                 ],
#                 [
#                     2692.73999,
#                     2706.389893,
#                     2692.050049,
#                     2713.340088
#                 ],
#                 [
#                     2710.110107,
#                     2708.639893,
#                     2703.6298829999996,
#                     2717.48999
#                 ],
#                 [
#                     2701.159912,
#                     2693.1298829999996,
#                     2681.899902,
#                     2702.840088
#                 ],
#                 [
#                     2692.560059,
#                     2670.139893,
#                     2660.

# %% [markdown]
# ### <font color='#2b4750' face='微软雅黑'>4.2 时间轮播图</font><a name='4.2'></a>
# [<font color='black' face='微软雅黑'>回到章首</font>](#4)
#
# 本例想画出不同时点 (每月月底) 时五只股票 (苹果、阿里巴巴、京东、脸书和高盛) 交易额 (价格×交易量) 的成分图。用 `Matplotlib` 则需要画 n 张饼状图，其中 n 为月份个数，但用 **`PyEcharts`** 里面的 `Timeline` 模块，可画出随时间线轮播动态图，一图可包含 n 张饼状图。首先读取包含五只股票的数据，做以下三个操作，
#
# - 保留 Date, Symbol, Adj Close 和 Volume 几列，最后两列是股票的收盘价和交易量 (用于计算交易额)
# - 从 Date 中获取 Year 和 Month 的信息并插入表中，用于根据年份和月份来分组。
# - 按 [Symbol, Year, Month] 分组，获取每只股票月底的数据

# %%
stock_data = pd.read_csv( '1Y Stock Data.csv', parse_dates=[0], dayfirst=True )

data = stock_data[['Date', 'Symbol', 'Adj Close', 'Volume']]
data.insert( 1, 'Year', pd.DatetimeIndex(data['Date']).year )
data.insert( 2, 'Month', pd.DatetimeIndex(data['Date']).month )
data.head(3).append(data.tail(3))
# Out:
#            Date  Year  Month Symbol   Adj Close    Volume
# 0    2018-02-26  2018      2   AAPL  176.285675  38162200
# 1    2018-02-27  2018      2   AAPL  175.714386  38928100
# 2    2018-02-28  2018      2   AAPL  175.448410  37782100
# 1257 2019-02-22  2019      2     GS  196.000000   2626600
# 1258 2019-02-25  2019      2     GS  198.649994   3032200
# 1259 2019-02-26  2019      2     GS  198.899994   2498000

# %%
def print_groups( group_obj ):
    for name, group in group_obj:
# 680 2018-11-05  2018     11     JD  24.150000  10519600
# 681 2018-11-06  2018     11     JD  23.600000  10321400
# 682 2018-11-07  2018     11     JD  24.070000  10476700
# ('JD', 2018, 12)
#           Date  Year  Month Symbol  Adj Close    Volume
# 699 2018-12-03  2018     12     JD  22.010000  19812700
# 700 2018-12-04  2018     12     JD  21.450001  18051400
# 701 2018-12-06  2018     12     JD  21.230000  20377400
# 702 2018-12-07  2018     12     JD  20.930000  13522900
# 703 2018-12-10  2018     12     JD  20.510000  14536300
# ('JD', 2019, 1)
#           Date  Year  Month Symbol  Adj Close    Volume
# 718 2019-01-02  2019      1     JD  21.270000  15840000
# 719 2019-01-03  2019      1     JD  20.350000  18608000
# 720 2019-01-04  2019      1     JD  22.270000  25156900
# 721 2019-01-07  2019      1     JD  22.760000  18889800
# 722 2019-01-08  2019      1     JD  22.950001  15180400
# ('JD', 2019, 2)
#           Date  Year  Month Symbol  Adj Close    Volume
# 739 2019-02-01  2019      2     JD  24.629999  11938200
# 740 2019-02-04  2019      2     JD  24.290001   9054300
# 741 2019-02-05  2019      2     JD  25.420000  19165600
# 742 2019-02-06  2019      2     JD  25.110001  11083100
# 743 2019-02-07  2019      2     JD  23.980000  15836100

# %%
group = grouped.apply( lambda df: df.iloc[-1,:] )
group.head(3).append(group.tail(3))
# Out:
#                         Date  Year  Month Symbol   Adj Close    Volume
# Symbol Year Month
# AAPL   2018 2     2018-02-28  2018      2   AAPL  175.448410  37782100
#             3     2018-03-29  2018      3   AAPL  165.263504  38398500
#             4     2018-04-30  2018      4   AAPL  162.781296  42427400
# JD     2018 12    2018-12-31  2018     12     JD   20.930000  19422400
#        2019 1     2019-01-31  2019      1     JD   24.850000  19318400
#             2     2019-02-26  2019      2     JD   26.590000  20264100

# %%
attribute = data.Symbol.unique()
n_stock = len(attribute)

MV = group['Adj Close'] * group['Volume']
value = np.reshape( MV.values, (n_stock,-1) ).T.tolist()
date = group['Date'].dt.strftime('%d-%b-%Y').unique()

tooltip_formatter = """function (params) {
        return '公司: ' + params.name  + 
            '<br>' + '市值: ' + window.parseFloat(params.value/100000000).toFixed(2) + ' 亿美元' +
            '<br>' + '占比: ' + params.percent + '%'
    }"""

timeline = Timeline()
for d, v in zip(date, value):
    pie = (
        Pie()
        .add(
            d,
            [list(z) for z in zip(attribute, v)],
            rosetype="radius",
            radius=["10%", "70%"],
            label_opts=opts.LabelOpts(
                # {a}（系列名称），{b}（数据项名称），{c}（数值）, {d}（百分比）
                formatter= "日期: {a} \n 公司：{b} \n 市值：{c} \n 占比：{d}% ",
                background_color="#eee",
                border_color="grey",
                border_width=1,
                border_radius=5),
            tooltip_opts=opts.TooltipOpts(formatter=JsCode(tooltip_formatter)),
        )
        .set_global_opts(title_opts=opts.TitleOpts(f"{d} 时公司市值"))
    )

    timeline.add(pie, d)

timeline.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="91ff11be1d36465384411737e9acf45b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_91ff11be1d36465384411737e9acf45b = echarts.init(
#                     document.getElementById('91ff11be1d36465384411737e9acf45b'), 'white', {renderer: 'canvas'});
#                 var option_91ff11be1d36465384411737e9acf45b = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "26-Feb-2019",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "AAPL",
#                         "value": 2964656014.012
#                     },
#                     {
#                         "name": "BABA",
#                         "value": 2543478868.9947
#                     },
#                     {
#                         "name": "JD",
#                         "value": 2239586744.2260003
#                     },
#                     {
#                         "name": "FB",
#                         "value": 496852185.01199996
#                     },
#                     {
#                         "name": "GS",
#                         "value": 538822419.0
#                     }
#                 ],
#                 "radius": [
#                     "10%",
#                     "70%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "roseType": "radius",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8,
#                     "formatter": "\u65e5\u671f: {a} \n \u516c\u53f8\uff1a{b} \n \u5e02\u503c\uff1a{c} \n \u5360\u6bd4\uff1a{d}% ",
#                     "backgroundColor": "#eee",
#                     "borderColor": "grey",
#                     "borderWidth": 1,
#                     "borderRadius": 5
#                 },
#                 "tooltip": {
#                     "show": true,
#                     "trigger": "item",
#                     "triggerOn": "mousemove|click",
#                     "axisPointer": {
#                         "type": "line"
#                     },
#                     "showContent": true,
#                     "alwaysShowContent": false,
#                     "showDelay": 0,
#                     "hideDelay": 100,
#                     "formatter": function (params) {        return '\u516c\u53f8: ' + params.name  +             '<br>' + '\u5e02\u503c: ' + window.parseFloat(params.value/100000000).toFixed(2) + ' \u4ebf\u7f8e\u5143' +            '<br>' + '\u5360\u6bd4: ' + params.percent + '%'    },
#                     "textStyle": {
#                         "fontSize": 14
#                     },
#                     "borderWidth": 0,
#                     "padding": 5
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "28-Feb-2018",
#                 "29-Mar-2018",
#                 "30-Apr-2018",
#                 "31-May-2018",
#                 "29-Jun-2018",
#                 "31-Jul-2018",
#                 "31-Aug-2018",
#                 "28-Sep-2018",
#                 "31-Oct-2018",
#                 "30-Nov-2018",
#                 "31-Dec-2018",
#                 "31-Jan-2019",
#                 "26-Feb-2019"
#             ]
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "AAPL",
#                         "BABA",
#                         "JD",
#                         "FB",
#                         "GS"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "28-Feb-2018",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "AAPL",
#                             "value": 6628809371.4609995
#                         },
#                         {
#                             "name": "BABA",
#                             "value": 3605085044.6323996
#                         },
#                         {
#                             "name": "JD",
#                             "value": 3349384691.481
#                         },
#                         {
#                             "name": "FB",
#                             "value": 807383166.2017
#                         },
#                         {
#                             "name": "GS",
#                             "value": 576540794.4556
#                         }
#                     ],
#                     "radius": [
#                         "10%",
#                         "70%"
#                     ],
#                     "center": [
#                         "50%",
#                         "50%"
#                     ],
#                     "roseType": "radius",
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8,
#                         "formatter": "\u65e5\u671f: {a} \n \u516c\u53f8\uff1a{b} \n \u5e02\u503c\uff1a{c} \n \u5360\u6bd4\uff1a{d}% ",
#                         "backgroundColor": "#eee",
#                         "borderColor": "grey",
#                         "borderWidth": 1,
#                         "borderRadius": 5
#                     },
#                     "tooltip": {
#                         "show": true,
#                         "trigger": "item",
#                         "triggerOn": "mousemove|click",
#                         "axisPointer": {
#                             "type": "line"
#                         },
#                         "showContent": true,
#                         "alwaysShowContent": false,
#                         "showDelay": 0,
#                         "hideDelay": 100,
#                         "formatter": function (params) {        return '\u516c\u53f8: ' + params.name  +             '<br>' + '\u5e02\u503c: ' + window.parseFloat(params.value/100000000).toFixed(2) + ' \u4ebf\u7f8e\u5143' +            '<br>' + '\u5360\u6bd4: ' + params.percent + '%'    },
#                         "textStyle": {
#                             "fontSize": 14
#                         },
#                         "borderWidth": 0,
#                         "padding": 5
#                     }
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "28-Feb-2018 \u65f6\u516c\u53f8\u5e02\u503c",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7

# %% [markdown]
# ### <font color='#2b4750' face='微软雅黑'>4.3 选项卡图</font><a name='4.3'></a>
# [<font color='black' face='微软雅黑'>回到章首</font>](#4)
#
# 选项卡式可将每张效果图进行全尺寸切换，而不必将其压缩到彼此相邻或重叠的位置。如果要展示的图多，选项卡图是最合适的形式。
#
# 定义函数 `Kline_func()` 返回 `Kline` 对象。

# %%
curr = 'EURUSD'
EURUSD = data_converter( currency_daily, curr, 'FX' )

def Kline_func(data, asset) -> Kline:
    date, price = data.index, data.values
    date_list = pd.to_datetime(date).strftime('%Y/%m/%d').tolist()

    kline = (
        Kline()
        .add_xaxis(date_list)
        .add_yaxis('', price.tolist())
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(is_scale=True),
            yaxis_opts=opts.AxisOpts(
                is_scale=True,
                splitarea_opts=opts.SplitAreaOpts(
                    is_show=True, 
                    areastyle_opts=opts.AreaStyleOpts(opacity=0.5)
                ),
            ),
            title_opts=opts.TitleOpts(title=asset +' Chart'),
            datazoom_opts=[opts.DataZoomOpts(type_='inside')],
        )
    )
    return kline

# %% [markdown]
# 定义函数 `Grid_func0()` 返回 `Grid` 对象。

# %%
stock_data = pd.read_csv( '1Y Stock Data.csv', parse_dates=[0], dayfirst=True )
stock_data.head().append(stock_data.tail())

data = pd.read_csv( 'S&P500.csv', index_col=0, parse_dates=True, dayfirst=True )
spx = data[['Adj Close']].loc['2018-02-26':'2019-02-26']

data = pd.read_csv( 'VIX.csv', index_col=0, parse_dates=True, dayfirst=True )
vix = data[['Adj Close']].loc['2018-02-26':'2019-02-26']

code = 'AAPL'

def Grid_func0(stock, code, index, vol) -> Grid:

    stock = stock[ stock['Symbol']==code ]

    date = stock['Date'].dt.strftime('%d-%b-%Y').tolist()
    price = stock[['Open','Close','Low','High']].values.tolist()

    kline = (
        Kline()
        .add_xaxis(date)
        .add_yaxis('', price)
        .set_global_opts(
            yaxis_opts=opts.AxisOpts(
                is_scale=True,
                splitarea_opts=opts.SplitAreaOpts(
                    is_show=True, 
                    areastyle_opts=opts.AreaStyleOpts(opacity=1)
                ),
            ),
            xaxis_opts=opts.AxisOpts(is_scale=True),
            title_opts=opts.TitleOpts(title=code, pos_top='25%'),
            datazoom_opts=[opts.DataZoomOpts(type_='slider',
                                             xaxis_index=[0, 1, 2],
                                             range_start=0,
                                             range_end=len(date),),
                           opts.DataZoomOpts(type_='inside',
                                             xaxis_index=[0, 1, 2],
                                             range_start=0,
                                             range_end=len(date),)],
        )
    )

    line1 = (
        Line()
        .add_xaxis(date)
        .add_yaxis(
                series_name='',
                y_axis=index.values.tolist(),
                markpoint_opts=opts.MarkPointOpts(
                    data=[opts.MarkPointItem(type_='min')]),
                is_smooth=True,
                is_hover_animation=False,
                linestyle_opts=opts.LineStyleOpts(width=3, opacity=0.5),
                label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(is_scale=True),
            yaxis_opts=opts.AxisOpts(is_scale=True),
            title_opts=opts.TitleOpts(title='SPX', pos_top='55%'),
        )
    )

    line2 = (
        Line()
        .add_xaxis(date)
        .add_yaxis(
                series_name='',
                y_axis=vol.values.tolist(),
                markpoint_opts=opts.MarkPointOpts(
                    data=[opts.MarkPointItem(type_='max')]),
                is_smooth=True,
                is_hover_animation=False,
                linestyle_opts=opts.LineStyleOpts(width=3, opacity=0.5),
                label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(is_scale=True),
            yaxis_opts=opts.AxisOpts(is_scale=True),
            title_opts=opts.TitleOpts(title='VIX', pos_top='75%'),
        )
    )

    grid_chart = Grid( init_opts=opts.InitOpts(width="1000px", height="600px") )

    grid_chart.add(
        kline,
        grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", pos_top="5%", height="40%")
    )
    grid_chart.add(
        line1,
        grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", pos_top="50%", height="15%")
    )
    grid_chart.add(
        line2,
        grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", pos_top="70%", height="15%")
    )

    return grid_chart

# %% [markdown]
# 定义函数 `Grid_func()` 返回 `Grid` 对象。

# %%
SP500 = pd.read_csv( 'S&P500.csv', index_col=0, parse_dates=True, dayfirst=True )
SP500 = SP500.loc['2018-02-26':'2019-02-26']

def Grid_func(data) -> Grid:

    date = pd.to_datetime(data.index).strftime('%Y/%m/%d').tolist()
    price = data[['Open','Close','Low','High']].values.tolist()
    close = data['Close']
    volume = data['Volume'].values.tolist()

    kline = (
        Kline()
        .add_xaxis(xaxis_data=date)
        .add_yaxis(
            series_name="S&P index",
            y_axis=price,
            itemstyle_opts=opts.ItemStyleOpts(color="#ec0000", color0="#00da3c", 
                                              border_color="#ec0000", border_color0="#00da3c"),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title="标普 500 指数",
                subtitle="MA5, MA20",
            ),
            xaxis_opts=opts.AxisOpts(type_="category"),
            yaxis_opts=opts.AxisOpts(
                is_scale=True,
                splitarea_opts=opts.SplitAreaOpts(
                    is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
                ),
            ),
            legend_opts=opts.LegendOpts(is_show=False),
            datazoom_opts=[
                opts.DataZoomOpts(
                    is_show=False,
                    type_="inside",
                    xaxis_index=[0, 1],
                    range_start=0,
                    range_end=100,
                ),
                opts.DataZoomOpts(
                    is_show=True,
                    xaxis_index=[0, 1],
                    type_="slider",
                    pos_top="90%",
                    range_start=0,
                    range_end=100,
                ),
            ],
            tooltip_opts=opts.TooltipOpts(
                trigger="axis",
                axis_pointer_type="cross",
                background_color="rgba(245, 245, 245, 0.8)",
                border_width=1,
                border_color="#ccc",
                textstyle_opts=opts.TextStyleOpts(color="#000", font_size=10),
                #formatter=JsCode(js_code_str),
            ),
            visualmap_opts=opts.VisualMapOpts(
                is_show=False,
                dimension=2,
                series_index=3,
                is_piecewise=True,
                pieces=[
                    {"value": -1, "color": "#ec0000"},
                    {"value": 1, "color": "#00da3c"},
                ],
            ),
            axispointer_opts=opts.AxisPointerOpts(
                is_show=True,
                link=[{"xAxisIndex": "all"}],
                label=opts.LabelOpts(background_color="#777"),
            ),
            brush_opts=opts.BrushOpts(
                x_axis_index="all",
                brush_link="all",
                out_of_brush={"colorAlpha": 0.1},
                brush_type="lineX",
            ),
        )
    )

    line = (
        Line()
        .add_xaxis(xaxis_data=date)
        .add_yaxis(
            series_name="MA5",
            y_axis=close.rolling(5).mean().tolist(),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=2, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="MA20",
            y_axis=close.rolling(20).mean().tolist(),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=2, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(xaxis_opts=opts.AxisOpts(type_="category"))
        )

    bar = (
        Bar()
        .add_xaxis(xaxis_data=date)
        .add_yaxis(
            series_name="Volume",
            y_axis=[
                [i, volume[i], 1 if price[i][0] > price[i][1] else -1]
                for i in range(len(data))
            ],
            xaxis_index=1,
            yaxis_index=1,
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                type_="category",
                is_scale=True,
                grid_index=1,
                boundary_gap=False,
                axisline_opts=opts.AxisLineOpts(is_on_zero=False),
                axistick_opts=opts.AxisTickOpts(is_show=False),
                splitline_opts=opts.SplitLineOpts(is_show=False),
                axislabel_opts=opts.LabelOpts(is_show=False),
                split_number=20,
                min_="dataMin",
                max_="dataMax",
            ),
            yaxis_opts=opts.AxisOpts(
                grid_index=1,
                is_scale=True,
                split_number=2,
            ),
            legend_opts=opts.LegendOpts(is_show=False),
        )
    )

    # Kline And Line
    overlap_kline_line = kline.overlap(line)

    # Grid Overlap + Bar
    grid_chart = Grid( init_opts=opts.InitOpts(width="1000px", height="600px") )

    grid_chart.add(
        overlap_kline_line,
        grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", height="50%")
        )
    grid_chart.add(
        bar,
        grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", pos_top="70%", height="16%")
    )

    return grid_chart

# %% [markdown]
# 定义函数 `Timeline_func()` 返回 `Timeline` 对象。

# %%
data_1Y = pd.read_csv( '1Y Stock Data.csv', parse_dates=[0], dayfirst=True )
data = data_1Y[['Date', 'Symbol', 'Adj Close', 'Volume']]
data.insert( 1, 'Year', pd.DatetimeIndex(data['Date']).year )
data.insert( 2, 'Month', pd.DatetimeIndex(data['Date']).month )
grouped = data.groupby(['Symbol', 'Year', 'Month'])
group_data = grouped.apply( lambda df: df.iloc[-1,:] )

def Timeline_func(data) -> Timeline:

    attribute = set([idx[0] for idx in group_data.index])
    n_stock = len(attribute)

    MV = group['Adj Close'] * group['Volume']
    value = np.reshape( MV.values, (n_stock,-1) ).T.tolist()
    date = group['Date'].dt.strftime('%d-%b-%Y').unique()

    tooltip_formatter = """function (params) {
            return '公司: ' + params.name  + 
                '<br>' + '市值: ' + window.parseFloat(params.value/100000000).toFixed(2) + ' 亿美元' +
                '<br>' + '占比: ' + params.percent + '%'
        }"""

    timeline = Timeline()
    for d, v in zip(date, value):
        pie = (
            Pie()
            .add(
                "",
                [list(z) for z in zip(attribute, v)],
                rosetype="radius",
                radius=["10%", "70%"],
                label_opts=opts.LabelOpts(
                    formatter= " 公司：{b} \n 市值：{c} \n 占比：{d}% ",
                    background_color="#eee",
                    border_color="grey",
                    border_width=1,
                    border_radius=5),
                tooltip_opts=opts.TooltipOpts(formatter=JsCode(tooltip_formatter)),
            )
            .set_global_opts(title_opts=opts.TitleOpts(f"{d} 时公司市值"))
        )

        timeline.add(pie, d)
        
    return timeline

# %% [markdown]
# 定义函数 `TreeMap_func()` 返回 `TreeMap` 对象。

# %%
data_US = pd.read_csv( 'US Stock Info.csv' )

def TreeMap_func(data) -> TreeMap:
    
    grouped = data.groupby(['sector'])
    group_value = grouped.apply( lambda df: np.sum(df['market_cap']) )
    data_for_treemap = []

    for i, grp in enumerate(grouped):

        total_mktcap, sector = group_value[i], group_value.index[i]
        code, r, mktcap = grp[1]['code'], grp[1]['return'], grp[1]['market_cap']

        children = []

        for j in range(len(code)):

            j_data = { 'value' : mktcap.iloc[j], 
                       'name': [code.iloc[j], r.iloc[j], sector] }

            children.append( j_data )

        i_data = { 'value' : total_mktcap,
                   'name': sector,
                   'children': children }

        data_for_treemap.append( i_data )

    label_formatter = """function (params) {
            sign = (params.name[1] > 0) ? '+' : '';
            return params.name[0] + '\\n' + sign + window.parseFloat(params.name[1]*100).toFixed(2) + '%'
        }"""

    tooltip_formatter = """function (params) {
        up_down_flat = (params.name[1] > 0) ? '涨' : (params.name[1] < 0) ? '跌' : '平';
        return params.name[0] + '<br>' + '行业: ' + params.name[2]  + 
        '<br>' + '市值: ' + window.parseFloat(params.value/100000000) + ' 亿美元' +
        '<br>' + '涨跌: ' + up_down_flat;
    }"""

    treemap = (
        TreeMap( init_opts=opts.InitOpts(width="1000px", height="600px") )
        .add("", 
             data_for_treemap,
             label_opts=opts.LabelOpts(position="inside", font_size=10, formatter=JsCode(label_formatter)),
             tooltip_opts=opts.TooltipOpts(formatter=JsCode(tooltip_formatter)),
            )
        .set_global_opts(title_opts=opts.TitleOpts(title="美股树形图"))
    )
    return treemap

# %% [markdown]
# 定义函数 `WordCloud_func()` 返回 `WordCloud` 对象。

# %%
def WordCloud_func(attr, count) -> WordCloud:
    wordcloud = (
        WordCloud()
        .add(series_name="",
             data_pair=[pair for pair in zip(attr,count)], 
             word_size_range=[20, 100]
            )
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title="王的机器用户分析", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
            ),
            tooltip_opts=opts.TooltipOpts(is_show=True),
        )
    )
    return wordcloud

# %% [markdown]
# 创建完 `Tab` 对象后，按顺序使用多个 `add()` 函数添加子图就行了，每个子图就是上面每个例子中定义的绘图函数。

# %%
tab = Tab()
tab.add(Kline_func(EURUSD, curr), "外汇 K 线图")
tab.add(Grid_func0(stock_data, "AAPL", spx, vix) , "苹果+SP500+VIX 多图")
tab.add(Grid_func(SP500), "标普 500 指数量价图")
tab.add(Timeline_func(group_data), "时间轮播图")
tab.add(TreeMap_func(data_US), "美股树形表图")
tab.add(WordCloud_func(attr, count), "王的机器用户图")
tab.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
#             padding: 6px 12px;
#             border-top: none;
#         }
#     </style>
# <div class="tab">
#             <button class="tablinks" onclick="showChart(event, '266ff305281b4447ba058b3d90941ad9')">外汇 K 线图</button>
#             <button class="tablinks" onclick="showChart(event, '59443b1274de4b1f911f0c9308dd3d7b')">苹果+SP500+VIX 多图</button>
#             <button class="tablinks" onclick="showChart(event, '5a276adda0a14f0f8ddef3b0879f1eed')">标普 500 指数量价图</button>
#             <button class="tablinks" onclick="showChart(event, '5bad9104bfc74cf28fe317ff7dc621d5')">时间轮播图</button>
#             <button class="tablinks" onclick="showChart(event, '98e9cce8460247a884ca8f471a74d5ea')">美股树形表图</button>
#             <button class="tablinks" onclick="showChart(event, '5f6a78917d1945d29c64243ecd641196')">王的机器用户图</button>
#     </div>
#
#         <div id="266ff305281b4447ba058b3d90941ad9" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="59443b1274de4b1f911f0c9308dd3d7b" class="chart-container" style="width:1000px; height:600px;"></div>
#         <div id="5a276adda0a14f0f8ddef3b0879f1eed" class="chart-container" style="width:1000px; height:600px;"></div>
#         <div id="5bad9104bfc74cf28fe317ff7dc621d5" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="98e9cce8460247a884ca8f471a74d5ea" class="chart-container" style="width:1000px; height:600px;"></div>
#         <div id="5f6a78917d1945d29c64243ecd641196" class="chart-container" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_266ff305281b4447ba058b3d90941ad9 = echarts.init(
#                     document.getElementById('266ff305281b4447ba058b3d90941ad9'), 'white', {renderer: 'canvas'});
#                 var option_266ff305281b4447ba058b3d90941ad9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "data": [
#                 [
#                     1.1341854333877563,
#                     1.1342240571975708,
#                     1.132169485092163,
#                     1.1380059719085693
#                 ],
#                 [
#                     1.135589361190796,
#                     1.135486125946045,
#                     1.1343270540237427,
#                     1.14177405834198
#                 ],
#                 [
#                     1.1343655586242676,
#                     1.1342884302139282,
#                     1.1315033435821533,
#                     1.1360280513763428
#                 ],
#                 [
#                     1.1347260475158691,
#                     1.13490629196167,
#                     1.132336139678955,
#                     1.1412267684936523
#                 ],
#                 [
#                     1.137682318687439,
#                     1.1374752521514893,
#                     1.1361312866210938,
#                     1.1410704851150513
#                 ],
#                 [
#                     1.140380859375,
#                     1.1400948762893677,
#                     1.1362345218658447,
#                     1.1445575952529907
#                 ],
#                 [
#                     1.135499119758606,
#                     1.1356538534164429,
#                     1.1307612657546997,
#                     1.1399389505386353
#                 ],
#                 [
#                     1.1322848796844482,
#                     1.1323105096817017,
#                     1.1316184997558594,
#                     1.138044834136963
#                 ],
#                 [
#                     1.137268304824829,
#                     1.1373459100723267,
#                     1.1333627700805664,
#                     1.139250636100769
#                 ],
#                 [
#                     1.1363248825073242,
#                     1.1363636255264282,
#                     1.1270780563354492,
#                     1.1366219520568848
#                 ],
#                 [
#                     1.130671739578247,
#                     1.1305949687957764,
#                     1.1304799318313599,
#                     1.1353960037231445
#                 ],
#                 [
#                     1.1349965333938599,
#                     1.1349835395812988,
#                     1.133863925933838,
#                     1.1403002738952637
#                 ],
#                 [
#                     1.1375658512115479,
#                     1.1375399827957153,
#                     1.1375658512115479,
#                     1.1439684629440308
#                 ],
#                 [
#                     1.138783574104309,
#                     1.1389521360397339,
#                     1.1378376483917236,
#                     1.1484880447387695
#                 ],
#                 [
#                     1.1457772254943848,
#                     1.1456853151321411,
#                     1.138783574104309,
#                     1.147446870803833
#                 ],
#                 [
#                     1.137203574180603,
#                     1.1372811794281006,
#                     1.137203574180603,
#                     1.143837571144104
#                 ],
#                 [
#                     1.1405109167099,
#                     1.140393853187561,
#                     1.1370097398757935,
#                     1.1422044038772583
#                 ],
#                 [
#                     1.1413440704345703,
#                     1.1415525674819946,
#                     1.137617588043213,
#                     1.1419435739517212
#                 ],
#                 [
#                     1.1363636255264282,
#                     1.1361312866210938,
#                     1.1359118223190308,
#                     1.1434321403503418
#                 ],
#                 [
#                     1.1430922746658325,
#                     1.143105387687683,
#                     1.1430922746658325,
#                     1.147315263748169
#                 ],
#                 [
#                     1.1438899040222168,
#                     1.1439945697784424,
#                     1.14223051071167,
#                     1.1465917825698853
#                 ],
#                 [
#                     1.1494252681732178,
#                     1.1493064165115356,
#                     1.146499752998352,
#                     1.155001163482666
#                 ],
#                 [
#                     1.1461317539215088,
#                     1.14617121219635,
#                     1.1345715522766113,
#                     1.1497001647949219
#                 ],
#                 [

# %% [markdown]
# ### <font color='#2b4750' face='微软雅黑'>4.4 页面图</font><a name='4.4'></a>
# [<font color='black' face='微软雅黑'>回到章首</font>](#4)
#
# 选项卡图是通过选标签来展示多图，顺序图是按顺序展示多图，包含三种布局方式：
#
# 1. DefaultPageLayout
# 2. SimplePageLayout
# 3. DraggablePageLayout
#
# 下面代码用 `SimplePageLayout` 来举例。代码非常易懂。创建完 `Page` 对象后，在一个 `add()` 函数中按顺序添加子图就行了。注意在选项卡图是分别用 `add()` 函数来添加子图的。两者的差异如下：
#
#     选项卡图	Tab().add( chart_1 ).add( chart_2 ). … .add( chart_n )
#     顺序图 	 Page().add( chart_1, chart_2, …, chart_n )

# %%
page = Page(layout=Page.SimplePageLayout)
page.add( Kline_func(EURUSD, curr), 
          Timeline_func(group_data), 
          TreeMap_func(data_US), 
          WordCloud_func(attr, count) )
page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="120e7e7bb4704eae9c525d11883f3718" style="width:900px; height:500px;"></div>
#         <div id="7c12fc9766d74baea81a830f25eda3f8" style="width:900px; height:500px;"></div>
#         <div id="1e8ed3514ff34cfd8a8f2b4239c44cd9" style="width:1000px; height:600px;"></div>
#         <div id="e311baeac0084d19b5e2207148b968d9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_120e7e7bb4704eae9c525d11883f3718 = echarts.init(
#                     document.getElementById('120e7e7bb4704eae9c525d11883f3718'), 'white', {renderer: 'canvas'});
#                 var option_120e7e7bb4704eae9c525d11883f3718 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "data": [
#                 [
#                     1.1341854333877563,
#                     1.1342240571975708,
#                     1.132169485092163,
#                     1.1380059719085693
#                 ],
#                 [
#                     1.135589361190796,
#                     1.135486125946045,
#                     1.1343270540237427,
#                     1.14177405834198
#                 ],
#                 [
#                     1.1343655586242676,
#                     1.1342884302139282,
#                     1.1315033435821533,
#                     1.1360280513763428
#                 ],
#                 [
#                     1.1347260475158691,
#                     1.13490629196167,
#                     1.132336139678955,
#                     1.1412267684936523
#                 ],
#                 [
#                     1.137682318687439,
#                     1.1374752521514893,
#                     1.1361312866210938,
#                     1.1410704851150513
#                 ],
#                 [
#                     1.140380859375,
#                     1.1400948762893677,
#                     1.1362345218658447,
#                     1.1445575952529907
#                 ],
#                 [
#                     1.135499119758606,
#                     1.1356538534164429,
#                     1.1307612657546997,
